# %%
import requests
from bs4 import BeautifulSoup
from time import sleep
import pandas as pd
import os
from urllib import parse
import numpy as np
import pymysql.cursors

# %% [markdown]
# 네이버 영화 메인 페이지 1~10위 영화 상세페이지 주소 가져오기

# %%
def step1_get_detail_url() :
    # 접속할 페이지의 주소
    site = 'https://movie.naver.com/movie/running/current.nhn?order=reserve'

    # 접속한다.
    response = requests.get(site)   

    bs = BeautifulSoup(response.content, 'html.parser')
    #print(bs)

    # a 태그들을 가져온다.
    a_list = bs.select('.top_thumb_lst a')

    # href 속성을 가져온다.
    df = pd.DataFrame()
    for idx in range(10) :       # 상위 20개만 가져오기
        href = a_list[idx].get('href')
        
        # 가져온 href 속성의 주소를 분석한 객체를 생성한다.
        a1 = parse.urlparse(href)
        
        # 주소를 분석한 객체서 쿼리 스트링을 가져온다
        query_str = parse.parse_qs(a1.query)
        
        # 추출한 쿼리스트링 데이터에서 원하는 파라미터 데이터를 추출한다.
        code = query_str['code'][0]
        

        # print(href)
        df = df.append([[code]], ignore_index=True)

    df.columns = ['code']
    return df
#     df.to_csv('movie_code_list.csv', index=False, encoding='utf-8-sig')
#     print('주소 저장 완료')

# %%
df=step1_get_detail_url()

# %% [markdown]
# 평점 더보기 주소 스크랩

# %%
def step2_get_reple_href(code_frame) :
    # 스크랩한 영화 코드를 불러온다.
    code_list = code_frame['code'].tolist()

    # 테스트용
 #   code_list = ['156464', '109906']


    # 영화코드와 주소를 합쳐서 요청할 주소를 만든다.
    url_list = pd.DataFrame()
    for code in code_list:
        site = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=%s&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false' % code
        # print(site)
        url_list = url_list.append([[site]], ignore_index=True)

    url_list.columns = ['url']
#     url_list.to_csv('movie_url_list.csv', index=False, encoding='utf-8-sig')
    return url_list

# %%
url_list=step2_get_reple_href(df)

# %% [markdown]
# 예매순 1~10 영화의 1페이지부터 마지막페이지 까지 순회하면서 평점과 리뷰 데이터 가져와서 저장

# %%
def step3_get_reply_data(df) :
    # csv에 저장되어 있는 url 데이터를 가져온다.
    url_list = df['url'].tolist()
    i=1 #영화 순위 카운팅
    result_df = pd.DataFrame()
    
    for url in url_list :
        print(url)
        # 해당 영화의 첫 페이지 html 데이터를 가져온다. (총 몇건의 리뷰가 있는지 확인해서 "페이지수"를 계산하기 위함)
        response = requests.get(url)
        bs = BeautifulSoup(response.content, 'html.parser')
        # print(bs)

        # 총 페이지 수를 구한다.
        strong = bs.select('.total em')
        #1->0
        score_total = int(strong[0].text.replace(',', ''))    # 쉼표 없애기 / int(정수형)로 만들기
        # print(score_total)
        pageCnt = score_total // 10     # 한페이지당 10개의 리뷰가 있어서
        if score_total % 10 > 0 :
            pageCnt += 1
        print(pageCnt)

        # 전체 페이지를 돌면서 140평 데이터를 가져온다.
        # 현재 페이지
        now_page = 1

        pageCnt = 5        # 테스트로 5페이지까지만
        
        while now_page <= pageCnt :
            #sleep(1)
            #sleep(0.0001)
            # 요청할 페이지의 주소
            url2 = url + '&page=' + str(now_page)
            # print(url2)

            # 140자평 데이터를 추출한다.
            response2 = requests.get(url2)
            bs2 = BeautifulSoup(response2.content, 'html.parser')

#             result_df = pd.DataFrame()

            # li 태그들을 가져온다.(score_reple 태그-리뷰-를 포함하고 있는)
            lis = bs2.select('.score_result li')

            for obj in lis :
        
                # 평점
                star_score = obj.select('.star_score em')[0].text
                # 140자평
                score_reple = obj.select('.score_reple p')[0].text
                # 아이디
                reviewer = obj.select('.score_reple em')[0].text
                # 날짜
                date = obj.select('.score_reple em')[1].text            
                # print(star_score)
                # print(score_reple)

                # 저장한다.
                result_df = result_df.append([[score_reple, star_score, reviewer, date, i]], ignore_index=True)
#             result_df.columns = ['text', 'score','reviewer', 'date', 'movie_id']
#             print(result_df)

#             if os.path.exists('star_score.csv') == False :     # 아직 파일이 없으면 파일을 만든다.
#                 result_df.columns = ['text', 'score']
#                 result_df.to_csv('star_score.csv', index=False, encoding='utf-8-sig')
#             else :                                               # 이미 파일이 있으면 결과를 더한다.
#                 result_df.to_csv('star_score.csv', index=False, encoding='utf-8-sig', mode='a', header=False)
                
            print("%d / %d" % (now_page, pageCnt))               # 진행경과를 보여준다. n번째 중 몇 번째 진행중인지.
            now_page += 1
        i=i+1 #movie_id 값 1증가
    result_df.columns = ['text', 'score','reviewer', 'date', 'movie_id']
    print('저장완료')
    return result_df

# %%
df=step3_get_reply_data(url_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f3377e5560f0> in <module>
# ----> 1 df=step3_get_reply_data(url_list)
#
# NameError: name 'url_list' is not defined

# %%
df.head(10)
# Out:
#                                                 text score  \
# 0  \n\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t...    10
# 1  \n\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t...    10
# 2  \n\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t...    10
# 3  \n\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t...    10
# 4  \n\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t...    10
# 5  \n\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t...    10
# 6  \n\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t...     8
# 7  \n\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t...     7
# 8  \n\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t...    10
# 9  \n관람객\n\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\...     8
#
#                      reviewer              date  movie_id
# 0  \n\nsereniTY(rldj****)\n\n  2020.05.06 20:13         1
# 1     \n\n영화매니아(yhib****)\n\n  2020.05.06 11:02         1
# 2      \n\n짱구아빠(cool****)\n\n  2020.05.06 14:45         1
# 3      \n\n눈누난나(lovn****)\n\n  2020.05.06 14:47         1
# 4  \n\n내일의내가하겠지(toie****)\n\n  2020.05.06 11:37         1
# 5       \n\n이연희(92-y****)\n\n  2020.05.09 23:25         1
# 6       \n\nRED(xx41****)\n\n  2020.05.06 12:44         1
# 7       \n\n빌헬미(jwjw****)\n\n  2020.05.06 15:22         1
# 8       \n\n김병근(dkzp****)\n\n  2020.05.06 19:59         1
# 9            \n\nraba****\n\n  2020.05.09 20:39         1

# %%
def prepro(df): 
    df.columns = ["리뷰","평점","작성자","날짜","movie_id"]

    df['리뷰']=df['리뷰'].str.replace(pat='관람객', repl='', regex=False)
    df[df['리뷰'].str.contains("스포일러가 포함된 감상평입니다. 감상평 보기")]= np.nan #nan으로 변경
    df['리뷰']= df['리뷰'].str.strip()  # 앞 뒤 공백을 제거
    df['작성자']= df['작성자'].str.strip()  # 앞 뒤 공백을 제거

    df=df.replace('',np.NaN)
    result=df.dropna()    
#     df.dropna()
    final_result=result.reset_index(drop=True)
    return final_result

# %%
df= prepro(df)

# %%
df.head(50)
# Out:
#                                                    리뷰  평점  \
# 0                              이것은... 사진 세울 때 쓰는 겁니다ㅎ  10
# 1   영화 재밌습니다. 다니엘 래드클리프 완전 열연이네요. 열쇠맞출때마다 몰입감과 긴장감...  10
# 2                        다니엘 래드클리프.. 이제는  배우로 도약하는거같다  10
# 3           심장 쫄리는 수준이 장난 아님. 말도 안 되는 것 같은데 실화라니 더 충격  10
# 4   코로나 탈출 방탈출 같이 갇힌 공간을 탈출하고 싶은 그 맘이 커서 그런지 재밌게 봤...  10
# 5                         나라면 그냥 12년 살았을듯....쫄려 죽는줄..  10
# 6                                        몰입도라든가 연출이좋음   8
# 7   껌으로 열쇠 붙일때가 젤 긴장감 있었다ㅋㅋㅋ 스토리는 실화기반이라 독특한 느낌은 없...   7
# 8   진짜 너무 재밌음 제빌 봐주세요 부탁임 이건 꼭 뵈야됨 콜라 빨대 오무리면서 봤네 ...  10
# 9                             긴장감,몰입감, 통쾌함을 느낀  재미난영화   8
# 10          영화속에 실제 탈출 주인공 나온다. . . 면회하는 장면. . . 잘바바요  10
# 11  그동안 봐온 감옥탈출 영화중 가장 소박했지만 열쇠라는 작은 매체 하나만으로 이렇게 ...   9
# 12                            이게 실화라니... 진짜 대단하다.. ㄷㄷ   9
# 13                       위험을 무릅쓰고 행동하는 자만이, 자유를 만끽하는법   9
# 14  배우들이 대사를 하는 시간보다 숨소리를 내는 시간이 더많은 영화오히려 그런 상황이 ...   7
# 15                         오 다니엘 래드클리프 인생 영화!  재밌어요~~  10
# 16                                  실화인데 영 믿기지가 않은 영화   8
# 17                        처음부터 끝까지 심장이 아주 쫄깃쫄깃 조여온다..   8
# 18  실화라는게 믿겨지지 않을 정도로 영화같은 스토리였네요, 코로나 때문에 오랜만에 간 ...   9
# 19                                        이런 영화 처음이네~  10
# 20                      아들과 봤음 조마조마 조마조마 실화 라니 정말 ...   8
# 21  15개의 강철문을 뚫는건 오로지 열쇠뿐!!!...시종 가슴을 조여오는 긴장감은 압권...  10
# 22  탈출영화 좋아해서 봤는데 직접 열쇠를 만들어버리는 클라쑤 ㅋㅋㅋㅋ 새로운 느낌이었는...   9
# 23  생각보다 자극적인 탈출 장면은 없어서 아쉽지만 들킬까봐 심장 쫄린 장면은 많았다. ...   7
# 24                           이야 몰입감쩔고 개쫄림 탈옥과정을 잘 표현함   8
# 25  긴장감 넘치는 연출로 몰입감이 좋아 시간가는 줄 모르고 빠져서 보게됩니다. 특히 실...   8
# 26  끝나는시간까지맘졸이며재미있게봤어요.실화가바탕이라고했으나내용을모르고가서인지보는내 긴장...  10
# 27  상황이 너무 맞아떨어지는 느낌도 들지만 탈출과정이 주는 몰입감은 최고... 더러운 ...   8
# 28                                  공포영화 보다도 더 심장터질뻔!  10
# 29           해리포터 이후 다니엘 래드클리프 작품 중에서 제일 나은듯 긴장감 장난아님   8
# 30              정적인 플롯이라고 생각했는데 생각보다 긴장감 넘치고 몰입됨. 재밌음   7
# 31  가학적인 장면 없이도 충분히 괴로운 영화 시종일관 꽉 죄어오는 긴장감이 관객을 괴롭힌다.   7
# 32  영화 볼 게 없어서 고른 건데 과몰입해서 봤음열쇠 껌으로 주울 때 긴장돼서 발가락을...   7
# 33  거짓말같은 실화라서 열쇠하나만으로도상영내내 긴장감 최고!인권운동가들에게응원과 박수를...  10
# 34                                        보다가 심장병 걸릴뻔   9
# 35                                해리포터의 아즈카반 탈출 영화화 ㅋ   9
# 36                                      진짜 짜릿해 ~~~~ 요  10
# 37      와~ 심장 쫄깃해 죽는줄 알았다... 이게 진짜 실화? 감옥 탈출 영화의 최고봉!  10
# 38                      내용도 재미있고 특히 실화라는게 ㅋㅋ임팩트 있었습니다  10
# 39                                  같이 탈옥 한번 한것 같은 기분   9
# 40                      극장에서 봐야하는 영화 was the best !:)  10
# 41                               몰입도가 좋아서 재미있게 잘봤습니다~   9
# 42  현실에 저항하는 것이 우리나라 독립운동가들 같기도 해서 응원(?)하면서 봤네요. 실...  10
# 43           내 인생 최고의 영화 꼭 보세요. 10점!! 불면증에 큰 도움이 됩니다.  10
# 44                    긴장감이 말이 필요없어요 꼭 보세요 간만에 인생영화 등극  10
# 45                            보다가 심장떨려서 죽을뻔했어용 꿀잼 ㅋㅋㅋ  10
# 46  영화를 끝까지 보고 나서도 이게 실화라는 게 믿기지 않을 정도로 정말 놀라운 감옥 ...  10
# 47                               말이 필요없음. 이런걸 영화라고 함.  10
# 48                                레미제라블이후로 휴잭맨의인생영화였다  10
# 49  휴잭맨의. 매력이 한껏 돋보인 영화입니다.다른 출연자들도 너무 멋지구요.사람은 누구...   9
#
#                      작성자                날짜  movie_id
# 0     sereniTY(rldj****)  2020.05.06 20:13       1.0
# 1        영화매니아(yhib****)  2020.05.06 11:02       1.0
# 2         짱구아빠(cool****)  2020.05.06 14:45       1.0
# 3         눈누난나(lovn****)  2020.05.06 14:47       1.0
# 4     내일의내가하겠지(toie****)  2020.05.06 11:37       1.0
# 5          이연희(92-y****)  2020.05.09 23:25       1.0
# 6          RED(xx41****)  2020.05.06 12:44       1.0
# 7          빌헬미(jwjw****)  2020.05.06 15:22       1.0
# 8          김병근(dkzp****)  2020.05.06 19:59       1.0
# 9               raba****  2020.05.09 20:39       1.0
# 10              wjoh****  2020.05.11 07:29       1.0
# 11        멘탈천국(5333****)  2020.05.07 22:22       1.0
# 12        계란머리(sdb9****)  2020.05.06 15:05       1.0
# 13              pon0****  2020.05.06 15:14       1.0
# 14        저녁노을(pqqv****)  2020.05.16 21:52       1.0
# 15        곰곰19(rhar****)  2020.05.06 11:39       1.0
# 16         epr(epro****)  2020.05.10 19:14       1.0
# 17  Sea Squirt(lcs6****)  2020.05.15 16:46       1.0
# 18        BLUE(heoj****)  2020.05.06 14:48       1.0
# 19         Joy(joy0****)  2020.05.06 13:34       1.0
# 20         타일러(itsh****)  2020.05.07 21:11       1.0
# 21         이남훈(nhsk****)  2020.05.08 10:58       1.0
# 22          리치(desi****)  2020.05.06 15:00       1.0
# 23          헬로(sunj****)  2020.05.14 11:09       1.0
# 24          문기(gye1****)  2020.05.13 16:09       1.0
# 25          꼴깍(yosu****)  2020.05.06 14:53       1.0
# 26              dude****  2020.05.08 18:38       1.0
# 27      castco(hand****)  2020.05.08 02:09       1.0
# 28              tjdg****  2020.05.14 12:25       1.0
# 29         클린봇(osy6****)  2020.05.08 03:24       1.0
# 30   Dayflower(hkh9****)  2020.05.10 23:07       1.0
# 31         토리파(manj****)  2020.05.11 03:18       1.0
# 32         김아름(yim4****)  2020.05.10 21:36       1.0
# 33         보리비(call****)  2020.05.15 16:30       1.0
# 34         REY(heyd****)  2020.05.11 00:52       1.0
# 35         불효자(silb****)  2020.05.07 19:47       1.0
# 36   treffshop(pdj4****)  2020.05.25 22:34       1.0
# 37        오늘밤새(inst****)  2020.05.16 08:55       1.0
# 38         한들꽃(jesu****)  2020.05.06 14:46       1.0
# 39         박종운(pgw0****)  2020.05.24 17:20       1.0
# 40   Amberlina(davi****)  2020.05.16 23:05       1.0
# 41              wooj****  2020.05.06 17:04       1.0
# 42         토마스(agac****)  2020.05.24 01:13       1.0
# 43          토루(tato****)  2020.05.23 18:11       1.0
# 44      제이비 JB(jbji****)  2020.05.17 00:55       1.0
# 45         che(rha0****)  2020.05.16 23:21       1.0
# 46      donnie(tech****)  2020.05.14 21:15       1.0
# 47              ryan****  2017.12.20 07:21       2.0
# 48         김도영(rlae****)  2017.12.20 00:03       2.0
# 49              sunn****  2017.12.20 15:19       2.0

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
import pickle
from konlpy.tag import *

# %%
# 형태소 분석을 위한 함수
def tokenizer(text) :
    okt = Okt()
    return okt.morphs(text)

# %%
df.head(50)
# Out:
#                                                    리뷰  평점  \
# 0                              이것은... 사진 세울 때 쓰는 겁니다ㅎ  10
# 1   영화 재밌습니다. 다니엘 래드클리프 완전 열연이네요. 열쇠맞출때마다 몰입감과 긴장감...  10
# 2                        다니엘 래드클리프.. 이제는  배우로 도약하는거같다  10
# 3           심장 쫄리는 수준이 장난 아님. 말도 안 되는 것 같은데 실화라니 더 충격  10
# 4   코로나 탈출 방탈출 같이 갇힌 공간을 탈출하고 싶은 그 맘이 커서 그런지 재밌게 봤...  10
# 5                         나라면 그냥 12년 살았을듯....쫄려 죽는줄..  10
# 6                                        몰입도라든가 연출이좋음   8
# 7   껌으로 열쇠 붙일때가 젤 긴장감 있었다ㅋㅋㅋ 스토리는 실화기반이라 독특한 느낌은 없...   7
# 8   진짜 너무 재밌음 제빌 봐주세요 부탁임 이건 꼭 뵈야됨 콜라 빨대 오무리면서 봤네 ...  10
# 9                             긴장감,몰입감, 통쾌함을 느낀  재미난영화   8
# 10          영화속에 실제 탈출 주인공 나온다. . . 면회하는 장면. . . 잘바바요  10
# 11  그동안 봐온 감옥탈출 영화중 가장 소박했지만 열쇠라는 작은 매체 하나만으로 이렇게 ...   9
# 12                            이게 실화라니... 진짜 대단하다.. ㄷㄷ   9
# 13                       위험을 무릅쓰고 행동하는 자만이, 자유를 만끽하는법   9
# 14  배우들이 대사를 하는 시간보다 숨소리를 내는 시간이 더많은 영화오히려 그런 상황이 ...   7
# 15                         오 다니엘 래드클리프 인생 영화!  재밌어요~~  10
# 16                                  실화인데 영 믿기지가 않은 영화   8
# 17                        처음부터 끝까지 심장이 아주 쫄깃쫄깃 조여온다..   8
# 18  실화라는게 믿겨지지 않을 정도로 영화같은 스토리였네요, 코로나 때문에 오랜만에 간 ...   9
# 19                                        이런 영화 처음이네~  10
# 20                      아들과 봤음 조마조마 조마조마 실화 라니 정말 ...   8
# 21  15개의 강철문을 뚫는건 오로지 열쇠뿐!!!...시종 가슴을 조여오는 긴장감은 압권...  10
# 22  탈출영화 좋아해서 봤는데 직접 열쇠를 만들어버리는 클라쑤 ㅋㅋㅋㅋ 새로운 느낌이었는...   9
# 23  생각보다 자극적인 탈출 장면은 없어서 아쉽지만 들킬까봐 심장 쫄린 장면은 많았다. ...   7
# 24                           이야 몰입감쩔고 개쫄림 탈옥과정을 잘 표현함   8
# 25  긴장감 넘치는 연출로 몰입감이 좋아 시간가는 줄 모르고 빠져서 보게됩니다. 특히 실...   8
# 26  끝나는시간까지맘졸이며재미있게봤어요.실화가바탕이라고했으나내용을모르고가서인지보는내 긴장...  10
# 27  상황이 너무 맞아떨어지는 느낌도 들지만 탈출과정이 주는 몰입감은 최고... 더러운 ...   8
# 28                                  공포영화 보다도 더 심장터질뻔!  10
# 29           해리포터 이후 다니엘 래드클리프 작품 중에서 제일 나은듯 긴장감 장난아님   8
# 30              정적인 플롯이라고 생각했는데 생각보다 긴장감 넘치고 몰입됨. 재밌음   7
# 31  가학적인 장면 없이도 충분히 괴로운 영화 시종일관 꽉 죄어오는 긴장감이 관객을 괴롭힌다.   7
# 32  영화 볼 게 없어서 고른 건데 과몰입해서 봤음열쇠 껌으로 주울 때 긴장돼서 발가락을...   7
# 33  거짓말같은 실화라서 열쇠하나만으로도상영내내 긴장감 최고!인권운동가들에게응원과 박수를...  10
# 34                                        보다가 심장병 걸릴뻔   9
# 35                                해리포터의 아즈카반 탈출 영화화 ㅋ   9
# 36                                      진짜 짜릿해 ~~~~ 요  10
# 37      와~ 심장 쫄깃해 죽는줄 알았다... 이게 진짜 실화? 감옥 탈출 영화의 최고봉!  10
# 38                      내용도 재미있고 특히 실화라는게 ㅋㅋ임팩트 있었습니다  10
# 39                                  같이 탈옥 한번 한것 같은 기분   9
# 40                      극장에서 봐야하는 영화 was the best !:)  10
# 41                               몰입도가 좋아서 재미있게 잘봤습니다~   9
# 42  현실에 저항하는 것이 우리나라 독립운동가들 같기도 해서 응원(?)하면서 봤네요. 실...  10
# 43           내 인생 최고의 영화 꼭 보세요. 10점!! 불면증에 큰 도움이 됩니다.  10
# 44                    긴장감이 말이 필요없어요 꼭 보세요 간만에 인생영화 등극  10
# 45                            보다가 심장떨려서 죽을뻔했어용 꿀잼 ㅋㅋㅋ  10
# 46  영화를 끝까지 보고 나서도 이게 실화라는 게 믿기지 않을 정도로 정말 놀라운 감옥 ...  10
# 47                               말이 필요없음. 이런걸 영화라고 함.  10
# 48                                레미제라블이후로 휴잭맨의인생영화였다  10
# 49  휴잭맨의. 매력이 한껏 돋보인 영화입니다.다른 출연자들도 너무 멋지구요.사람은 누구...   9
#
#                      작성자                날짜  movie_id
# 0     sereniTY(rldj****)  2020.05.06 20:13       1.0
# 1        영화매니아(yhib****)  2020.05.06 11:02       1.0
# 2         짱구아빠(cool****)  2020.05.06 14:45       1.0
# 3         눈누난나(lovn****)  2020.05.06 14:47       1.0
# 4     내일의내가하겠지(toie****)  2020.05.06 11:37       1.0
# 5          이연희(92-y****)  2020.05.09 23:25       1.0
# 6          RED(xx41****)  2020.05.06 12:44       1.0
# 7          빌헬미(jwjw****)  2020.05.06 15:22       1.0
# 8          김병근(dkzp****)  2020.05.06 19:59       1.0
# 9               raba****  2020.05.09 20:39       1.0
# 10              wjoh****  2020.05.11 07:29       1.0
# 11        멘탈천국(5333****)  2020.05.07 22:22       1.0
# 12        계란머리(sdb9****)  2020.05.06 15:05       1.0
# 13              pon0****  2020.05.06 15:14       1.0
# 14        저녁노을(pqqv****)  2020.05.16 21:52       1.0
# 15        곰곰19(rhar****)  2020.05.06 11:39       1.0
# 16         epr(epro****)  2020.05.10 19:14       1.0
# 17  Sea Squirt(lcs6****)  2020.05.15 16:46       1.0
# 18        BLUE(heoj****)  2020.05.06 14:48       1.0
# 19         Joy(joy0****)  2020.05.06 13:34       1.0
# 20         타일러(itsh****)  2020.05.07 21:11       1.0
# 21         이남훈(nhsk****)  2020.05.08 10:58       1.0
# 22          리치(desi****)  2020.05.06 15:00       1.0
# 23          헬로(sunj****)  2020.05.14 11:09       1.0
# 24          문기(gye1****)  2020.05.13 16:09       1.0
# 25          꼴깍(yosu****)  2020.05.06 14:53       1.0
# 26              dude****  2020.05.08 18:38       1.0
# 27      castco(hand****)  2020.05.08 02:09       1.0
# 28              tjdg****  2020.05.14 12:25       1.0
# 29         클린봇(osy6****)  2020.05.08 03:24       1.0
# 30   Dayflower(hkh9****)  2020.05.10 23:07       1.0
# 31         토리파(manj****)  2020.05.11 03:18       1.0
# 32         김아름(yim4****)  2020.05.10 21:36       1.0
# 33         보리비(call****)  2020.05.15 16:30       1.0
# 34         REY(heyd****)  2020.05.11 00:52       1.0
# 35         불효자(silb****)  2020.05.07 19:47       1.0
# 36   treffshop(pdj4****)  2020.05.25 22:34       1.0
# 37        오늘밤새(inst****)  2020.05.16 08:55       1.0
# 38         한들꽃(jesu****)  2020.05.06 14:46       1.0
# 39         박종운(pgw0****)  2020.05.24 17:20       1.0
# 40   Amberlina(davi****)  2020.05.16 23:05       1.0
# 41              wooj****  2020.05.06 17:04       1.0
# 42         토마스(agac****)  2020.05.24 01:13       1.0
# 43          토루(tato****)  2020.05.23 18:11       1.0
# 44      제이비 JB(jbji****)  2020.05.17 00:55       1.0
# 45         che(rha0****)  2020.05.16 23:21       1.0
# 46      donnie(tech****)  2020.05.14 21:15       1.0
# 47              ryan****  2017.12.20 07:21       2.0
# 48         김도영(rlae****)  2017.12.20 00:03       2.0
# 49              sunn****  2017.12.20 15:19       2.0

# %%
def step7_insert_review(df) :
    # 객체를 복원한다.
    with open('pipe.dat', 'rb') as fp:
        pipe = pickle.load(fp)

    import numpy as np
    import pandas as pd
    
    
    rlist=df["리뷰"].tolist()
    df=df.drop("리뷰",axis=1) 
    df_result = pd.DataFrame()
    
    for i in rlist :
        text = i

        str = [text]
        # 예측 정확도
        r1 = np.max(pipe.predict_proba(str) * 100)
        # 예측 결과
        r2 = pipe.predict(str)[0]

        if r2 == '1' :
            print(text)
            
            print('긍정적인 리뷰')
            df_result = df_result.append([[text, r1, r2]],ignore_index=True)
            print('----------------------------')
        else :
            print(text)
            print('부정적인 리뷰')
            df_result = df_result.append([[text, r1, r2]],ignore_index=True)
            print('----------------------------')

        print('정확도 : %.3f' % r1)
    
    df_result.columns = ['리뷰','정확도','결과']
    final_result=pd.concat([df_result,df],axis=1)
    return final_result

# %%
final_result = step7_insert_review(df)
# Out:
# 이것은... 사진 세울 때 쓰는 겁니다ㅎ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.861
# 영화 재밌습니다. 다니엘 래드클리프 완전 열연이네요. 열쇠맞출때마다 몰입감과 긴장감이 공존하는데 꿀잼입니다. 올해 본 영화 중 탑 3에 들어감. 저게 실화라는게 더 놀랍네요.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.708
# 다니엘 래드클리프.. 이제는  배우로 도약하는거같다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.575
# 심장 쫄리는 수준이 장난 아님. 말도 안 되는 것 같은데 실화라니 더 충격
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.623
# 코로나 탈출 방탈출 같이 갇힌 공간을 탈출하고 싶은 그 맘이 커서 그런지 재밌게 봤음 방탈출카페 가고 싶다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.916
# 나라면 그냥 12년 살았을듯....쫄려 죽는줄..
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 89.424
# 몰입도라든가 연출이좋음
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.318
# 껌으로 열쇠 붙일때가 젤 긴장감 있었다ㅋㅋㅋ 스토리는 실화기반이라 독특한 느낌은 없었다. 쇼생크 탈출류의 감옥이야기
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.764
# 진짜 너무 재밌음 제빌 봐주세요 부탁임 이건 꼭 뵈야됨 콜라 빨대 오무리면서 봤네 ㅋㅋㅋㅋ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.418
# 긴장감,몰입감, 통쾌함을 느낀  재미난영화
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.931
# 영화속에 실제 탈출 주인공 나온다. . . 면회하는 장면. . . 잘바바요
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 89.525
# 그동안 봐온 감옥탈출 영화중 가장 소박했지만 열쇠라는 작은 매체 하나만으로 이렇게 스릴을 유도하는 경우는 개인적으로 처음 봐서 실화이지만서도 참신하게 다가온 작품이었습니다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.633
# 이게 실화라니... 진짜 대단하다.. ㄷㄷ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 93.684
# 위험을 무릅쓰고 행동하는 자만이, 자유를 만끽하는법
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.672
# 배우들이 대사를 하는 시간보다 숨소리를 내는 시간이 더많은 영화오히려 그런 상황이 보는 입장에서 더긴장하게 만듬.쇼생크 탈출을 보러 왔다가  이스케이프 플랜(실버스타 스텔론)의 과거 버전을 보고 온듯한 기분
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 91.622
# 오 다니엘 래드클리프 인생 영화!  재밌어요~~
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.924
# 실화인데 영 믿기지가 않은 영화
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 94.002
# 처음부터 끝까지 심장이 아주 쫄깃쫄깃 조여온다..
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.898
# 실화라는게 믿겨지지 않을 정도로 영화같은 스토리였네요, 코로나 때문에 오랜만에 간 극장이였는데 후회 없습니다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.109
# 이런 영화 처음이네~
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 91.429
# 아들과 봤음 조마조마 조마조마 실화 라니 정말 ...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.728
# 15개의 강철문을 뚫는건 오로지 열쇠뿐!!!...시종 가슴을 조여오는 긴장감은 압권이다!!!...유색인종 인권운동으로 실형을 받은 두명의 백인!그들의 탈출은 부당함에 맞서는 유일한 방법!실화가 주는 진정성은 울림이 ...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.607
# 탈출영화 좋아해서 봤는데 직접 열쇠를 만들어버리는 클라쑤 ㅋㅋㅋㅋ 새로운 느낌이었는데 실화였다니 더 소름! 그 와중에 연기도 잘함
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.349
# 생각보다 자극적인 탈출 장면은 없어서 아쉽지만 들킬까봐 심장 쫄린 장면은 많았다. 보통 생각하는탈출극이다만 긴장감 있는 탈출을 보고 싶다면 추천
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.871
# 이야 몰입감쩔고 개쫄림 탈옥과정을 잘 표현함
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.731
# 긴장감 넘치는 연출로 몰입감이 좋아 시간가는 줄 모르고 빠져서 보게됩니다. 특히 실화를 리얼하게 살려낸 연출에 찬사를 보냅니다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.477
# 끝나는시간까지맘졸이며재미있게봤어요.실화가바탕이라고했으나내용을모르고가서인지보는내 긴장의시간이었어요.추천합니다~
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.043
# 상황이 너무 맞아떨어지는 느낌도 들지만 탈출과정이 주는 몰입감은 최고... 더러운 장면 하나 있어서 별 하나 깎음
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.151
# 공포영화 보다도 더 심장터질뻔!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.580
# 해리포터 이후 다니엘 래드클리프 작품 중에서 제일 나은듯 긴장감 장난아님
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.886
# 정적인 플롯이라고 생각했는데 생각보다 긴장감 넘치고 몰입됨. 재밌음
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.709
# 가학적인 장면 없이도 충분히 괴로운 영화 시종일관 꽉 죄어오는 긴장감이 관객을 괴롭힌다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.990
# 영화 볼 게 없어서 고른 건데 과몰입해서 봤음열쇠 껌으로 주울 때 긴장돼서 발가락을 가만히 두질 못하고 ㅋㅋㅋ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.169
# 거짓말같은 실화라서 열쇠하나만으로도상영내내 긴장감 최고!인권운동가들에게응원과 박수를 보냅니다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.524
# 보다가 심장병 걸릴뻔
# 부정적인 리뷰
# ----------------------------
# 정확도 : 68.565
# 해리포터의 아즈카반 탈출 영화화 ㅋ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.834
# 진짜 짜릿해 ~~~~ 요
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.980
# 와~ 심장 쫄깃해 죽는줄 알았다... 이게 진짜 실화? 감옥 탈출 영화의 최고봉!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.587
# 내용도 재미있고 특히 실화라는게 ㅋㅋ임팩트 있었습니다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.266
# 같이 탈옥 한번 한것 같은 기분
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.281
# 극장에서 봐야하는 영화 was the best !:)
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.302
# 몰입도가 좋아서 재미있게 잘봤습니다~
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.546
# 현실에 저항하는 것이 우리나라 독립운동가들 같기도 해서 응원(?)하면서 봤네요. 실화라는 게 놀랍고 강한 저항의지에 감동받았어요. 지루할 틈 없이 스릴있어요.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.568
# 내 인생 최고의 영화 꼭 보세요. 10점!! 불면증에 큰 도움이 됩니다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.670
# 긴장감이 말이 필요없어요 꼭 보세요 간만에 인생영화 등극
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.989
# 보다가 심장떨려서 죽을뻔했어용 꿀잼 ㅋㅋㅋ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 91.874
# 영화를 끝까지 보고 나서도 이게 실화라는 게 믿기지 않을 정도로 정말 놀라운 감옥 탈출기를 보여주는데요. 단순한 스토리지만 끝까지 숨 막히는 전개에 아직 못 보셨다면 꼭 챙겨 보시라고 강추 드릴만 한 영화였습니다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.790
# 말이 필요없음. 이런걸 영화라고 함.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 93.296
# 레미제라블이후로 휴잭맨의인생영화였다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.925
# 휴잭맨의. 매력이 한껏 돋보인 영화입니다.다른 출연자들도 너무 멋지구요.사람은 누구나 소중하며, 현재를 멋지게 사는게 중요하다는 메세지도 있구요.좋았습니다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.919
# 지금 미국에선 평론가들 평 안좋고, 관객평은 좋다던데 우째 딱 영화 처럼 된듯ㅋㅋㅋ "공연을 즐기지 못하는 공연 평론가 이게 진짜 사기 아닌가요?"
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 94.824
# 정말 인생 최고의 영화!!!! 너무 좋아서 울컥하고 남들 없었음 ㅠ 기립박수 칠뻔!! 강추!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.749
# 노래 진짜 쩐다 ㅠㅠㅠ 보는 내내 귀호강 ! 그리고 배우분들 연기 다 너무 좋아서 올해 마무리 영화로 딱인듯합니다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.824
# 시작한 지 얼마 안되어서부터 꿈을 얘기하는데 듣다보면 눈물이 난다. 그 꿈이 허황되기 때문일까 쉽게 꿈꿀 수 없는 그 꿈이 아름답기 때문일까. 생각보다 묵직한 음악으로의 시작이라 좋았고 처음 들어보는 잭 에프론의 목...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.199
# 좀 뻔한 전개 스토리이긴 하지만 아주 재밌게 봤고 감동적이었습니다. 실화 영화인 것을 생각하니 더욱 좋았습니다. 가족이나 아주 친한 사람들과 함께 보면 아주 좋을 영화입니다. 명대사들이 많이 나오고 기대 이상이었습니...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.182
# 올해 최고의 뮤지컬 영화입니다단언컨데 꼭 다시한번 볼것입니다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.930
# 라라랜드 보다 재밌다. 10만원이 넘는 비싼 뮤지컬 보다 1만원이 안되는 위대한 쇼맨이 한 수 위. 한해를 마무리하면서 세상을 살아가는데에는 역시 함께와 용기라는 생각을 다시 하게 해 주어서 좋았다. 연말에 가족들이...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.732
# 생각했던 거보다 기대 이상으로 재미있었고요 노래가 나올 때마다 온몸에 소름이 돋았습니다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.389
# 진짜 재미있음 라라랜드보다 잼남
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.165
# 감히 말하자면 올해 본 영화중에 최고였음. 노래도 어쩜 하나같이 다 명곡임.. 가사 하나하나 너무 좋음ㅠㅠㅠ 다들 꼭 보세요. 후회하는일 없을거에요!!!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.670
# 제 2의 레미제라블 제2의 라라랜드아님 그냥 위대한 쇼맨임!!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 91.847
# 인생영화 하나 또 나옴, 연말에 가족들끼리 한번 더 봐도 너무 좋을 듯 합니다 : )
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.638
# 이정도면 상영중에 박수타임 가져야돼는거 아닌가.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.583
# “This is me!” 당연하면서도 울컥한 한마디였다. 다른 사람들의 눈치 보느라 정작 나에 대해서는 몰랐고 그게 당연해졌었다. 그들의 외침에 스스로를 몰랐던 나에게 부끄러웠고 시원했고 당당해졌다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.221
# 휴잭맨 오프닝~ 대박!!!! 노래계속 따라불러요
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.227
# 이영화를 본다면 너도 리뷰를 쓰고있을것이다 꼭봐라 노래트랙 하루종일 틀것이다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.217
# 점왜 이영화 말이 없나 했더니 .. 이런 반전이 .. 졸라 재밌어
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.172
# 영화 끝나고도 자리를 못 뜰 정도로 여운이 남네요
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 94.799
# 화려한 쇼만 기대했다가 대반전 ㄷㄷ스토리도 끝까지 너무 좋구 ㅜ 메세지가 감동적이네여
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 89.739
# 내생애최고영화 ㅠㅠ 완벽하다정말
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.907
# 하루에 두 번 본 유일한 영화...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.170
# 젝 에프론, 젠다야 둘의 목소리 조합은 진짜ㅠㅠ꿀떨어짐요ㅠㅠ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.976
# 방금 조조로 보고 나왔는데 스토리 라인은 그렇게 막 깔끔하진 않았음 하지만 음악이랑 춤이 모든걸 만회함 진짜 귀호강 제대로
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.509
# 와 이최고의 영화 이번년도의 마무리는 이영화다. 정말 최고 최고 최고 이말보다 더 할말이 없다. 보면서 눈물이 벅차오르는 감정과 흘러내렸다. 가슴이 뛴다 이영화를 봐라 인생영화다 음악과 영상미 진실 그리고  돈의 ...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.976
# 뮤지컬영화 중에서 가장 영상미와 노래의 탄탄한 균형이 잡힌 작품이라고 생각합니다. 눈과 귀가 즐거웠고, 잠시나마 동화의 세계로 들어갔다 나온 기분입니다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.890
# 와...이게뭐지..너무 화려해...서커스가 이렇게재밌었구나
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 89.791
# 영화보다 박수칠뻔했습니다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 90.615
# 제니린드 노래부를때 휴잭맨 표정 = 내 표정입 벌리고 봄
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.068
# 들어갈땐 9천원 입장료였지만나올땐 9만원 위대한 쇼였다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.433
# 이 영화보면 OST를 자꾸 듣게 되는 후유증이 생깁니다..ㅠ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.155
# 올해 최고의 뮤지컬 영화
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.988
# 이런거 원래 안 남기는데 이건 개쩐다 걍
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 91.331
# 누구의 눈에는 한 순간의 쇼 혹은 오락일 수 있지만, 다른 누군가에게는 한 순간의 삶이 될 수 있다면
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.715
# 양옆에서 오열하는 가운데 혼자 섹시해진 잭 에프론에 감탄하면서 봄...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.621
# 뮤지컬과 거리가 먼 나였는데, 이거보고 깜놀!!! 또 볼거임
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 94.021
# 큰 기대 없이 보러온 건데, 노래도 좋고 영상도 화려해서 볼 거리가 많았습니다. 칼라일이 잘생겼어요. 최근 다양성에 대한 이슈가 불거지는데, 그것에 대해서도 생각해볼 거리가 있다고 생각됩니다. 그리고 칼라일이 잘생겼...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.099
# 뭔가 나도 모르게 엔딩에서 박수침 ㅋ 한편의 뮤지컬을 본듯
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.513
# 기대안하고 봤는데 재밌었음. 이런 영화는 영화관에서 안보면 재미가 반감될듯. 영화관에서 보길 적극 추천
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.846
# 2시간 동안 행복해 지고 싶다면 이 영화를 보세요~ 모두에게 초강추!!!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.952
# 와 평점 달아본 적 없는데 진짜 노래가 하나같이 다 좋다 미쳤다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.336
# OST, 군무가 다했다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.512
# 노래땜에 운건 처음이다 ㅠ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 94.325
# 휴잭맨이 대박이겠구나 했더니 조연들까지 내 맘을 뺏음.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.708
# 주제에걸맞게구성지고재밌다휴잭맨당신을엔터테이너로임명합니다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.905
# 시사회로 봤었는데 정말 재밌었어요^^
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.147
# 휴 잭맨 잭 애프론 호흡 역시 남성들의 뮤지컬의 향수를 느꼈다 휴 잭맨 레미제라블 그리고 잭 애프론 하이스쿨 뮤지컬의 이어 정말 명작 뮤지컬 영화를 실망 안 시키게 잘 소화해냈다 연말 이 영화를 봐도 돈이 안 아까울...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.026
# 휴잭맨은 정말 빛이났고 한명도 묻히는 캐릭터없이각자의 역할이 다 빛났어요 보통 뮤지컬영화관람하면 수록곡중 2~ 3곡 정도만 좋다고 느끼는데 전체적으로 다 좋아요 ㅠㅠ발을 가만히 둘수가 없었어요 일어나서 춤추고싶더라구...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.550
# 내 '벨에포크'는 언제인지 생각하게 되는 영화! 영상미도 너무 이쁘고 무엇보다 핸드메이드 시간여행이라는 컨셉이 너무너무 신박했음!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.166
# "세상이 큰 재떨이 같았어." 마리안에게는 어둠의 1974년이 빅토르에겐 찬란한 빛이었음을.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.312
# 뜻밖의 감동과 여운이 길게 남는 영화. 마지막 엔딩 꼭 놓치지 마세요. 눈물이 왈칵 나서 혼났어요.. 강력 추천합니다!!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.901
# 아쉽다 높은 완성도를 가질수 있었을거 같은데..2프로 부족한 영화
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 91.351
# 익숙함에 속아 소중함을 잃지말자란 말이 떠오르네요
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.324
# 매력적인 시간여행 로맨스! 아 이 맛에 로맨스 영화 보는거지 싶었다. 소중한 사람이랑 같이 보면 더 좋을 듯
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.514
# 감동이다.. 눈물났다 할아버지 눈빛과 연기에. 늙어도 사랑은 필요하고 추억을 공유한 옆에 있는 사람에게 잘해주자
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.897
# 너무 사랑스럽고 아름다운 영화. 다니엘 오떼유와 화니 아르당의 연기가 허를 찌른다. 이 영화를 보고 울어버릴 줄은 예상하지 못했다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.426
# 제 마음이 다 설레였어요 너무너무 좋았습니다!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.598
# 초반 적응하는데  인내심이 필요한 프랑스감각영화.15세가 관람할 영화는 아닌것같은데..
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.834
# 내 첫사랑처럼 귀엽고 소중해서 마음속에 영원히 간직하고 싶은 영화네요~ 꼭 한번 봐보세요
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.664
# 어제 시사회에서 보고 아직 빠져있는중! 인생영화 등극! 컨셉도 좋지만 여운이 남는 감동.. 힐링되는 기분! 강강추
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.753
# 추억으로 남은 과거는 사랑스럽고 달콤하다. 초심을 떠올릴 수 있다. 그러나 거기에 함몰되면 안 된다는 듯, 마지막에는 모두의 담배가 꺼진다. 아쉬운듯 과거의 환영을 보며 잠시 담뱃불을 붙여보지만, 이내 금방 꺼버린다...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.371
# 프랑스 썅송판 부부의 세계
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 93.166
# 이런 시간여행 영화라면 언제든지 반갑다!! 당장 내가 떠나고 싶은, 주변 사람들에게 마구마구 알려주고 싶은 시간여행! 영화 보는 내내 훈훈하고 웃기고 울고 따뜻하고 다했다! 화면은 또 얼마나 예쁜지, 극장에서 보길 ...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.354
# 노래가 너무 좋고 엄마한테 보여주고 싶은 영화였어요
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.536
# 젊음과 나이듬에 따른 사랑의 온도차, 부부에 대한 현실등이 공감이 간다. 배우들의 연기도 좋고, 각 인물들간의 미묘한 감정선도 잘살려서 몰입하게 만들고, 마지막 울컥하게 만드는 부분 까지 자연스럽게 이어지는 특이한 ...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.846
# 진짜 오랜만에 잘 자고 왔습니다... 컨셉도 모르겠고 불륜이 왜 거기서 감동 포인트가 되는지도 모르겠고...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 54.962
# 컨셉도 신선하고 영화 좋았어요
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 94.789
# 이게 왜 9.65인지,, 개연성이 부족하고 감동 포인트가 없어요. 소재만 참신.
# 부정적인 리뷰
# ----------------------------
# 정확도 : 84.402
# 오랜만에 극장에서 몰입해서 영화 본 것 같다. 시간여행 영화를 원래 좋아하지만 핸드메이드 시간여행이라니 그것만으로도 새롭고 나라면 언제로 돌아가고 싶을까 이런 생각, 부모님 생각도 하게 만들어준 영화. 시간되면 다시...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.490
# 전형적인 넷플릭스 드라마 본 느낌. 소재는 참신했으나 결말로 갈수록 이해도와 몰입도가 떨어지는 영화임. 불필요한 성적 표현 씬이 너무 많음.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 75.882
# 전반적으로 괜찮은데 앙투안이 설득력이 너무 떨어짐 그냥 미친놈 같고
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 62.261
# 누구에게나 화영연화는 있다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.108
# 진짜 개강추 올해 본 영화 중 가장 영화다운 영화였음
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.164
# 우리와 정서가 다른 프랑스 사람들의 인생관과 사랑법을 보여주는 영화다. 조커같은 인상의 여배우가 주인공이라 좀 깼지만 말도 안되는 설정을 현실감있게 몰입하게 한 것은 배우들의 열연.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.046
# 좋았어요 생각이 많아지는 영화
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.962
# '내 사랑의 시작과 끝은 너야'이 말이 가장 잘 어울리는♡
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.333
# 주연 남자배우의 감정연기가 대단합니다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.331
# 노년의 성에 대해 노골적으로 묘사되어 있어요 19금 영화로 했어야 합니다공감할 수 있는 연령대가 높아요~~성행위에 대한 수위만 낮았어도 좀 더 괜찮았을..어른들의 감성팔이 영화..감동이라기 보단 씁쓸하네요
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.400
# 생각지도 못하게 감동을 느낄 수 있었던 영화! 요즘 같은 때에 힘든 마음에 위로가 되는 영화가 아닌가 싶다!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.918
# 진짜...소재도 연출도 너무 신선함 ㅠㅠ핸드메이드로 시간여행을 한다는게 좀 감이안왔는데 이걸 이렇게 표현할 수가 있구나 싶었음. 스토리, 연출, 내용, ost다 넘 좋아서 부모님 모시고가서 봐도 좋을듯!! 요즘 날씨...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.610
# 100% 핸드메이드 시간여행이라는 신선한 상황이 너무 좋았습니다.화면 또한 너무 이쁘게 나와 만족감도 110% 입니다.적극 추천 합니다~!!^^
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.906
# 평점 낮게 준 사람들이 보통 영화 내의 연애관이라든지 성 등등 으로 몰입이 안된다는거 같은데, 그 점을 배제하고도 충분히 볼만한 영화입니다. 영상미나 음악도 좋았구요. 70년대 코스튬, 히피스러운 분위기 모두 흥미롭...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 88.475
# 힘든날 우연히 보고 잠시나마 내 아름다운 추억를 기억하게한 영화
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.062
# 평점에 알바를 조금 쓰신 것 같아요 영화 줄거리만 보고 기대하며 봤는데 처음과 마지막은 괜찮았지만 중간에 좀 " 잉; " 스러운 내용이 좀 있었어요 결말은 생각했던 대로 흘러갔지만 그 과정이 개인적으로...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 60.627
# 독특하고 외국의 정서가 좀 맞지 않아 이해를 하면서 봐야했어요솔직히 저는 높은 평점에 비해 나쁘지도 아주 좋지도 않은 정도였어요
# 부정적인 리뷰
# ----------------------------
# 정확도 : 78.849
# 오랫동안 못잊을 영화!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.188
# 비슷한 순간 비슷하지만 다른 감정
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.132
# 타임슬립인줄 알았는데,,아니였네요 ㅎ일부러 예고편도 안보고갔어요잼있게 봤습니다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.654
# 여운남고 ..좋았어 생각하게 만드는 영화
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.389
# 중간에 조금 졸리긴했는데 영상미 너무 이쁘고, 스토리가 신선하기도 하고 연기 훌륭했어요
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 82.665
# 커플들 보러가서 서로 다른 사람 생각해서 다 헤어져라>_<ㅋ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 84.191
# 새로운시도 시성세대의 가치관이 과거에 잡혀 현실에 부적응하는모습....마지막
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.420
# 중간에 보다 나왔습니다. 개인적으로 제 스타일은 아니네요
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 51.480
# 사랑이 그리움이 그래서 다시 사랑하는
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.430
# 현재를 사랑하게 만드는 영화
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.527
# 이 영화를 보고 룸메보다 일찍 일어나야 한다는 교훈을 얻었습니다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.930
# 정말 많은 생각을 하게 만듬. 근데 요리만드는사람들에대해 좀더 설명좀 해주면 좋겠음 러닝타임도 짧은데
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 93.484
# 소재가 강렬하면서 신선하고 혐오스러우면서 공감 가는, 생각을 많이 하게 하는 영화
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.218
# 뭐랄까. 감독이 얘기하고자하는 것은 단순해서 잘알겠는데. 마지막에 정리가 안되는 느낌? 곡성과 같이 생각을 하고싶어지는 마지막이 아니라. 그냥 마지막 정리는 나도 안되니 니들이 알아서해? 라는 느낌
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 93.195
# 설정이 일단 개신박함... 결국은 어떻게 살 것인가에 대한 질문을 던지는 생각하게 만드는 영화
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.370
# 인간의 마음이 사회 구조를 어떻게 만드는지, 사회 구조가 인간의 마음을 어떻게 만드는지.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.558
# 용두사미 용두사미용두사미
# 부정적인 리뷰
# ----------------------------
# 정확도 : 74.285
# 비빔밥 비빔밥 비빔밥 비빔밥 비빔밥
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 94.212
# ㅋㅋㅋㅋ처음에 유투브에서예고편보고 와되게참신하고 새로운소개고 재밋겟네 생각되서 보러가서 초중반까지 그냥볼만하게 봣는데 중반후반부터 뭔되도안되는 환영이계속나타나서 몰입방해하고 시원한 결말도없고 엔딩도 개ㅈ망임 절대비추...
# 부정적인 리뷰
# ----------------------------
# 정확도 : 56.166
# 넷플릭스를 거치는 영화&드라마 특징: 소재 좋고 연기력 괜찮고 초 중반 잘끌고감 그리고 항상 마지막은 개빡치게 다 열린결말
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.197
# 설국 열차의 수직 버전! 스토리가 긴장감 있고 재밌어요!!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.022
# 생존 방법을 잘 표현한듯
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.102
# 인육 먹는 것을 "살기 위해 어쩔 수 없다"고 했던 건 , 시스템에 저항하지 않는 게으름에 대한 변명 아니었을까. 공포를 동력으로 한 경쟁은 우리사회와 닮아있다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.998
# 메세지는 있다. 메세지를 전달하는 방법에 대해서는 글쎄. 특히 플랫폼의 부당에 저항하는 인물(모두가 함께 살아갈 방법을 강구하는 인물)이 살기 위해 본능적으로 음식앞으로 다가오는 아래층 사람들을 가차없이 처치(?)하...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.402
# 주인공이 즐라탄 닮아서 몰입감이... 좋았다ㅎ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.374
# 죄수의 딜레마를 생각나게 한다.그런데 음식을 고르게 먹었어도 다 못먹었을거 같은데
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.594
# 충격적인 여운, 스릴러로서의 장르적 재미는 100%
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 88.132
# 머리를 띵 맞은 듯. 설국열차보다 매운 맛 블랙스릴러.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 94.439
# 120분 영화였으면 좋겠다. 결말이 조금 허무한듯,
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.013
# 와~ 이 짧은 영화에 안에 사회적으로 많은 뜻이 있다니... 돈키호테는 소름~
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.066
# 조금은 잔인할수 있지만 인간의 본성을 잘 살린 영화인듯
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.841
# 난 당연히 사무라이 플러스
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 93.504
# 아오 지루해  더럽고 3류
# 부정적인 리뷰
# ----------------------------
# 정확도 : 69.665
# 수직적인 계층구조와 가진 자들에게 못 가진 자들의 형편따위는 안중에도 없음을 잘 드러낸 영화.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 94.890
# 많은 생각을 하며 보던 중 정신병자 싸이코에 안하무인에 눈찢어진 동양인이라고 대놓고 동양인 비하. 돈내고 인종차별 당함 무식한 영화
# 부정적인 리뷰
# ----------------------------
# 정확도 : 75.053
# 인간은 이기적인 동물이라는 걸 가감없이 확실하게 보여준다. 그리고 판나코타를 맛보고 싶은 욕구가 생긴다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 90.497
# 지도자와 주동자, 피지배자조차 망각한 주최자의 목적. 무엇에 또 어떤 의미에 의해 시스템은 작동하고 작동 되는지는 미지수에, 단순히 주어진 체계에만 순응하는 개개인들. 괴로움에 최선의 변명은 어찌할 도리가 없었음....
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.817
# 큐브+설국열차 또보고싶을만큼 여운을 남김
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.201
# 결말이 좀 찝찝했다. ㅜㅜ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 94.952
# 올해 가장 충격적인 영화입니다 설정이 신박하고 몰입감이 대박입니다!!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.657
# 처음엔 뭔가 스토리가 있을 것 같았지만 끝으로 갈수록 깔아놓은 스토리에 대한 답을 하나도 회수못하고 어떻게 끝맺어야할지 감독도 몰라서 대중한테 떠넘긴 영화 전반적인 스토리 구상은 좋았으나 애매한 마무리와 해석으로 이...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 87.896
# 마 의리게임 모르나 의리게임
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 94.535
# 이영화 보면서 나는 내인생을 확인 했는데.너무 좋은 영화 였습니다. 뻔하지만 보면 내삶을 다시 보게끔 해준 영화 였습니다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.244
# 미친 컨셉; 보기 전 부터 기대했는데 기대 이상이었음메시지와 재미 다 잡은영화 ㅋㅋㅋ 강추입니다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 87.855
# 밥상이 공포가 되는 기똥찬 스릴러 ㅎㄷㄷ 아직도 손에 땀이
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 93.307
# 신박한스토리 ㅋㅋ 근데 마지막엔 이게 끝이야? 진짜? 하게됌 개연성은 진짜 개나줘버리고... 걔네들은 왜 거기에 있는지 요리사들은 어떻게 그런곳에서 일하고있는지 16살 미만은 못들어온다면서 애는 왜 거기에있는지
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 73.111
# 유투브 리뷰 보고 재밌을거 같아서 청불인지도 모르고 남친이 예매했대서 신나서 보러 갔는데... 끝나고 회 먹기로 했었는데.... 다음날까지도 속 안 좋고 진짜 너무 징그럽고 잔인하고 역겨운 영화였어요.... '...
# 부정적인 리뷰
# ----------------------------
# 정확도 : 63.535
# "비빔밥을 좋아한다"
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.350
# 확실히 곱씹을 부분이 많은 영화예요. 인간의 본능이란 무엇인지.. 의미를 해석하면서 보는 재미가 있어요. 리뷰를 많이 읽어보려고 합니다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 92.469
# 다음편에는 올라가는 내용인가
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 84.194
# 자본주의 본질을 플랫폼으로 꿰 뚫다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 94.474
# 이걸 보고 막창을 먹은 내가 레전드!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.844
# 결말 없는 영화.. 그리고 계속 같은 배경이어서 너무 지루함. 비싼 먹방보는 느낌.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 53.262
# 스토리 연출 배우 셋팅 메시지 모두 역겨운 영화. 1시간 30분의 완전한 낭비.
# 부정적인 리뷰
# ----------------------------
# 정확도 : 77.101
# 구덩이라는 공간의 설정에 대해서 충분히 설명해주지 않아서 몰입이 전혀 안 됩니다. 각 인물의 성격 같은 것도 너무 메시지를 주기 위해 설정된 것 같아서 몰입을 방해하구요. 인간의 추악함과 계급구조 등을 우화적으로 표...
# 부정적인 리뷰
# ----------------------------
# 정확도 : 52.124
# 영화는 반복적으로 바뀌는 레벨이라는 체계 속에서 볼 수 있는 인간의 포악함을 적나라하게 표현했습니다, 주인공은 그 과정에서 만나게 되는 다양한 인간의 사상과 생존방식을 여러방면에서 표현하여 룸메이트가 상징하는 각각의...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.998
# 인간이 두려움에 잠식 당할때 인간성을 유지 할 수 있는가.  당신이 믿고 있던 신념이 무너질때 얼마나 깊은 곳까지 추락 할 수 있는가.  수 없이 많은 은유들을 날것 그대로 표현한다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.816
# 정신병자들의 리얼 스토리를 10500원이나 주고 보다니요. 감독 은퇴작이 아니고서야 설명되지 않는 영화!  수직 감옥에서의 음식의 재분배를 통해 연대의식을 설명하고자 하는 거는 알겠지만 그마저도 마무리가 확실하지 않...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.293
# 더빙판 걱정반 기대반 봤는데 생각보다 웬디랑 로운 연기가 자연스럽고 어색하지 않아서 놀랬음. 노래도 기대 이상으로 잘해서 더빙판이 매우 흡족스러움. 아이돌이 연기하면 더군다나 더빙하면 진짜 기대는 커녕 걱정만 하고 ...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.057
# 웬디 노래 넘 잘해요..연기도 자연스럽고..별 기대안했는데 생각보다 정신없이 봤네요..8살은 정말재밌다네요..
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.830
# 트롤들 다 귀여워요ㅠㅠㅠ 그리고 웬디랑 로운 더빙 정말 잘해서 깜짝놀랐어요 !!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.215
# 진짜 재밌어요 특히 웬디님 목소리가 대박이에요 ㅠㅠ다들 더빙으로 꼭 한번 보고 오세요
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.510
# 더빙으로봤는데 너무좋았어요!!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.768
# 코로나로 우중충한 분위기를 넘나 경쾌하게 띄워주는 귀요미들.. 극장하고  VOD 동시에 개봉하는 방법도 괜찮은 듯 하다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.798
# ost 짱 좋아요 보다가 케이팝 트롤에 레드벨벳 나와서 반가웠네요ㅋㅋㅋㅋ 가사도 우리말로 나오고!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.151
# 트롤들이 너무 졸귀탱이야ㅠㅠ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.658
# 오랜만에 본 트롤 아이들도 너무좋아했고 방가웠어요중간중간 나오는 노래도 재밌고 내용또한 재미났어요
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.809
# 진짜 무료한 일상중에 신나게 영화 잘봤어요 !! 특히 트롤들이 너무 귀여워서 ㅠ ost도 넘 좋고 중간에 살짝 레드벨벳 노래 나와서 더 신났어요 !! 추천합니다 !
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.862
# 케이팝트롤 나올 때 뭔가 넘 반갑고 ㅋㅋㅋ 트롤들도 러블리하고 노래들이 다 넘 신나서 기분 좋게 봤음
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.325
# 보는 내내 둠칫둠칫 행복했어요 롹 트롤 아주 매력적 후후
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.328
# 트롤들 너무 귀여운거 아니냐며...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.066
# 재밌어요애기들이 많아서 좀 관크가 있긴하지만웬디랑 로운 목소리가 넘 잘어울려요
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.893
# 트롤 1 처럼 먹힌다는 잔인한 주제가 아닌 사람들이 좋아하고 즐기는 음악을 주제로해서 정말 재밌었어요!그리고 쿠키영상이 없어서 좀 아쉽네요ㅠㅠ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.792
# 처음 평점 남겨봅니다 아무정보 없이 갔는데 너무 즐겁고 90분이 30분처럼 느껴졌어요 오랜만에 극장가에 담비같은 영화개봉 해서 좋구요^^ 레드벨벳 곰슬기 트롤 카드? 받고 놀랬어욬ㅋ굿!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.230
# 완전 신나고 좋네요ㅎㅎ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.114
# 레드벨벳 짧지만 너무 귀엽고 러시안룰렛 칼군문도 너무 귀여웠어요!! 웬디의 파피 더빙은 더더욱 멋지고 재밌게봤어요 레드벨벳 최고!!!!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.686
# 캐릭터들이 너무 매력있고, 폭포나 강 같은 배경 표현이랑 스크랩북같은 연출들이 너무 재밌고 귀여워요ㅜ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.459
# OST  맛집 트롤 진짜 ㅠㅠㅠ 이번 월드투어도 노래들 다다 너무 좋음!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.548
# 아이때문에 보러간건데 제가 더 재밌게 보고왔어요 더빙도 너무 좋았어요 ^^
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.479
# 너무너무 기다렸었던 영화였는데 기대했던만큼 너무 귀엽고 노래도 신나구 행복했어요ㅠ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.333
# 트롤졸귀다재밋어용ost도좋음
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.089
# 둠칫둠칫둠칫둠칫
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.316
# 음악도신나고내용도신나요
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.101
# 연예인 더빙이라 좀 걱정했는데 웬디가 학창시절 뮤지컬 주연을 자주 해봐서 그런지 좋았습니다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.067
# 너무 재미있어요. 특히 로운님과 웬디님이 연기를 잘해주셔서 더 몰입감이 있었어요
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.824
# 믿고 듣는 트롤 ost... 최고예요 더빙 다 보고 지금 멜론으로 트롤 ost 들으면서 자막 보러 갑니다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.261
# 로운님과 웬디님의 목소리가 좋았고 하나도 안 어색했어요! 두분 다 가수라 그런지 ost도 귀호강 하면서 들었습니다!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.525
# 웬디랑 로운 더빙 정말 잘해서 너무 놀랐고 너무 신남 ㅋㅋㅋ내용도 재밌고 무엇보다 귀호강 눈호강 대박
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.451
# 아이도 신나고엄마도 신났어요♡
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.308
# 영상 많이 봤는데 너무 신나고 잼나요 ㅋㅋㅋ노래 막 흥얼거리게 돼요 ㅋㅋㅋ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.944
# 트롤들 너무 귀엽고 vod 동시개봉 진짜 감사합니다ㅠㅠ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.721
# 생각보다 아는 노래 많이 나오고 신났음 ㅋㅋ 캐릭터들도 귀엽고
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.293
# 더빙이랑 자막 둘 다 봤는데 더빙이 좀 더 한국정서에 맞고 맛깔났음. 웬디랑 로운이 생각보다 더빙을 너무너무 잘했음. 노래 다양한 장르 나오는데 노래 다 좋았음. 케이팝갱 분량 아쉬웠지만 영화 좋았음.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.657
# 로운 더빙 너무 잘하고 노래도 너무 좋아요ㅠㅠ 웬디도ㅠ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.445
# 1편은 안봤는데 앞에 요약해주는? 부분이 있어서 괜찮았어요. 의외로 어른들이 봐도 흥겨울 포인트가 많았어요. 나오는 노래들 다 좋고 강남스타일 짐살라빔 나올때 진짜 ㅋㅋ 인도영화처럼 춤추면서 보고싶은 마음이! 결말도...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.453
# 캐릭터들이 하나하나 다 귀여움ㅋㅋㅋost는 계속 듣게 생겼네
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.137
# 웬디 더빙 너무 잘해서 놀랐어요
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.529
# 솔직히 더빙판 불안해하면서 봤는데 웬디가 연기를 정말 잘 살려주네요. 오히려 목소리에 푹 빠져서 나중엔 주인공이 답답한짓을 해도 그저 사랑스럽게 느껴주더라고요.Ost도 정말 사랑스럽고 영화 자체내용도 정말 재밌었어요...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.406
# 성인 여성이 소녀처럼 꺄르르 웃다가 아이처럼 슬퍼졌다가 아주 흥에겨워 리듬까지 타다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.527
# 모든 음악이 좋았지만 그 중 테크노 트롤들 음악이 너무 좋았다. 그리고 딩클스 너무너무 기여워ㅠㅠ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.302
# 귀와 눈은 만족스럽고 심지어 감동까지 ...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.051
# 와 노래가 너무 좋은거 같음!!둠칫둠칫!!ㅋㅋ신이난다는코로나때문에 영화관도 못가고 했는데!!완전 기대되영~~
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.805
# 노래도 신나고 영상도 예쁘고 넘넘 귀여운 영화인듯 합니당ㅎㅎ 귀여운게 최고얌
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.318
# 귀가 즐겁고 귀여운 트롤들이 너무 좋았어요!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.817
# 웬디가 더빙을 정말 생각보다 너무 잘해서 깜짝놀랐음 ㅜㅜㅠ 노래는 말할것도 없고..!  내용은 딱 아이들이 좋아할만함
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 94.815
# 1편안봤는데 트롤들이 너무 귀엽고 신나요! 락트롤이 젤 신나는것이..ㅋㅋㅋ 재즈트롤 시강쩔구여ㅋㅋㅋㅋ 강추~!!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.134
# 웬디가 더빙을 너무 잘했어요! 스토리도 재미있었습니다!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.379
# 더빙 vod로 봤는데 노래도 부르고 그러니까 흥얼흥얼거리면서 신나게 봤네요
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.280
# 최고의 영화.. 아직도 가슴이 먹먹하고 눈물이 나온다. 장국영이 보고싶다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 92.954
# 이 정도면 인류의 유산이라고 평가하고 싶다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.764
# 내 인생 최고의 영화. 나의 영화감상은 패왕별희를 보기전과 보고난 후로 나뉘어질 정도다. 평점 10점도 짜다고 생각함. 시나리오의 탄탄함과 그것을 완벽함으로 이끌어낸 배우들의 연기력. 최고다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.398
# 20여년전 어릴 적 봤을 때도 임펙트가 대단했는데 나이먹고 보니 더 대단하다...패왕별희를 능가할 중국영화가 다시 나올 수 있을까도 궁금하다...장국영은 이 영화로 영원히 살아 숨쉬는거야,.,.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.377
# 극 속 우희의 삶도 삶이지만 집단 사고가 얼마나 무서운 전염병인지 절실히 느꼈다. 누군지도 모를 사람의 한마디에 휩쓸려 인민들이 쉽사리 말을 바꾸고 목청을 높이는 대목이 너무나도 소름끼쳤다...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.637
# 물밀듯 쳐들어오는 한나라 앞에서 자결한 우희, 물밀듯 쳐들어오는 시대 앞에서 자결한 데이.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.250
# 역시나 지금까지 인구에 회자되는 명작은 다르다. 인생과 사랑과 예술과 역사가 서로 오묘하게 교직되어 공명하면서도 충돌하고, 모순되면서도 합일을 이루어낸다. 어떤 영화가 인간의 삶을 이토록 다양한 각도에서 총체적으로 ...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.585
# 보다 미칠수도 있음 ....
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.404
# 지림
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.629
# 예술은시대로부터자유로워야한다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.895
# 패왕별희를 흉내낼 수 있는 영화는 있을 수 있으나 패왕별희가 주는 그 충격적인 느낌과 감정들은 이 영화에서밖에 느낄 수 없다. 이쁘지도 않고 거칠며, 우아하지도 않고 투박하다. 하지만 눈을 뗄 수 없고 잊혀지지 않는...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.745
# 예술이 경지에 다다르면 대중성을 갖게 된다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.802
# 할말이 없다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 91.440
# 데이와 쥬산의 저마다의 사랑이 서글픈 영화
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.977
# 장국영이라는 배우가 지금 이 세상에없다는게 정말 안타깝다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.435
# 한평생을 원했던 도즈
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.759
# 장국영을 추억하게 해주는 영화중 하나. 그리고 내 인생 최고의 영화. 이런 대작이 다시 나올 수 있을까?
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.968
# 방금 봤다. 마지막 때문에 지금 혼이 빠져나간 느낌. 말로 설명할 수 없는 여운...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.904
# 짙은 경극분장에 가려진 그들의 삶
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.175
# 이 영화에 별점을 매긴다는것은 말이 되지 않는다 하지만 이영화를 본후 나의 감정을 누구에게든 알리고 싶었다 말이 필요없다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.231
# 장국영연기에 한번 더 놀란 영화ㅋ마지막 표정은 잊을수 없다 최고..
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.728
# 영화본후엔 세상 다 산거같은 느낌들어서 싫지만 또 언젠가 찾아보겠지
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.347
# 내가 태어나서 본 영화 중 가장 아름답다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.106
# 동양 최고의 명작, 지루하지 않습니다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.793
# 이 영화는 세계문화유산으로 지정되어야 합니다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.993
# 데이가 곧 장국영이었고 장국영이 곧 데이였다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.696
# 장국영과 함께 영화팬들 가슴속에 영원히 기억될 영화.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.757
# 주샨만이 데이를 이해해준 영화
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.140
# 장국영의 위엄ㄷㄷ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.435
# 10점으로도 부족하다. 명작이다. 첸카이거 감독의 다른 영화들도 보고 싶어졌다. 물론, 장국영과 장풍의, 공리 또한 대단했다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.597
# 난 본디 사내아이로 계집아이도 아닌데
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.346
# 영화를 다 감상하고 난 후 머리가 어지럽고 정신이 아득하다. 영화 보는 내내 화면에서 눈을 뗄 수 없다. 영화에 감사하다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.170
# 한편의 영화이상의 가치를 지닌 영화.... 영화라고 하기엔 그 영향이 너무나 크다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.470
# 희노애락이 담긴 한편의 경극처럼, 휘청거리던 데이의 한이 서린 인생사.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.623
# 극찬  정도가  아니라..뭐랄까.. 평가를 한다는 것 자체가 우스워진다고 할까.. 뭐라고 논할 수가 없다..논하기에 너무 죄송스러워서..장국영은 아마 평생 리즈로만 기억될 듯...장국영의 모든 연기 하나 하나가 설레...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.000
# 장국영연기 진짜....
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.033
# 장국영을 왜 이리 늦게 알게 되었을까 ...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.070
# 이걸 동성애영화로 본 당신은 영화를 잘못 봤다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.827
# 예술이 영원할 수 밖에 없는 이유를 알게되었습니다. 누구나 부딪히게되는 인생의 무게가 고스란히 느껴지는 영화였습니다. 예술혼이란 바로 이런것...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.114
# 말도 안되는 영화 감히 명작 20년이 흘러도 먹먹함은 말로 못다하네요 손끝까지 연기하는 장국영..
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.618
# 이 영화가 10점이 아니면 10점일 영화가 몇편이나 될까
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.823
# 장국영의 눈빛이 잊혀지지가 않는다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.607
# 무슨 왕의 남자랑 비교를 하나. 감히
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.270
# 김포공항 롯데시네마  4시 20분 영화 h10번 9번 앉은 커플새1끼들 존1나 시끄럽고 핸드폰은 대체 왜 쳐 꺼낸건지 이해가 안가네 특히 여자분 제발 영화볼때는 입닥치고 보세요
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.094
# 당연히 10점 먹고 들어간다. 최고의 영화로 손색없다. 찬사를 받을 만한 장국영의 연기.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.764
# 장국영의 영혼이 깃든 영화. 눈빛으로 수 만가지를 말하다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.160
# 한 떨기의 꽃이 시대와 함께 지는 것을 목격했다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.747
# 아! 어린 시절에 봐도 좋은 영화란 것을 어렴풋이 알았는데 어른이 된 지금 보니.. 정말 엄청난 영화구나. 슬프고 아름답다..
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.482
# 왜 명작인지 알 수 있음..그와중에 장국영 연기는 최고..3시간이 너무 빨리가서 꿈꾼것 같은 기분
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.649
# 가끔 어떤 배우들을 보면 카메라에 영혼을 배출하는 듯한 느낌까지 주는 배우들이 존재하는데 장국영이 바로 그 대표적인 예이다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.237
# 꿀잼 웃으면서 보기좋음
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.087
# 영화속서 속사포같이 나오는 욕설과 액션이 아주 찰지고 시원한 영화
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.505
# 퓨리와 데드풀의 환장의 조합
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.017
# 휴일 부담없는 영화로는 굿
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 92.130
# 두 주연 모두 다른 작품임에도 불구 퓨리와 데드풀의 연장선 같다. 하지만 이빨까기는 세계 최고
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.296
# 봤던거지만 또봐도재미짐  난또 영화에삭제된 장면   나올줄알았는데  그냥 캐릭터소개  내용이네 ㅋㅋ  그래도  라이언과  사무엘 둘의 콤비는진짜 재밌고 웃김  둘이또  영화찍어줬으면  ㅋ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.783
# 사무엘 잭슨 짱이다~할배 재롱 칭찬해.동사서독 리덕스나 지옥의 묵시록 리덕스나 블레이드 러너 감독판(디렛터스 컷)이나 파이널 컷만큼은 아니지만?
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 80.860
# 좀보고얘기해라 18!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.779
# 개그코드 안맞음. Soso
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 92.250
# 몇년만에 봐도 재밌다 라이언이랑 사무엘젝슨 티키타카가 진짜 최고
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.621
# 와 ㅋㅋ진짜 미쳤엌남자친구랑 같이 봤는데 이 영화에서 잼있는 포인트를 말하기 힘들어여 모든 장면이 다 웃기고 잼있어옄
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.622
# 개그도 액션도 모조리 챙겼다!!!!1
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 93.882
# 브로맨스 입담, 의외로 찰진 액션
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.448
# 시종일관 티격태격하지만 유쾌한 콤비 플레이 작렬..그리고 게리 올드만의 카리스마 있는 악당 역할
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.925
# 겁나 꿀잼
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 94.211
# good good good
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.686
# 라이언 레이놀즈의 매력과 사무엘 잭슨의 연기가 케미를 이룬 재미있는 영화였습니다무삭제 감독판이라 배우들의 소회도 볼수 있어 좋았어요
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.456
# 좋게말하면 자연스러운 영화. 안 좋게 말하면 너무 티 안나서 본편과 차이점이 모르겠는 영화. 그냥 피가 많이 흐르는 영화? 마지막에 잠시 나오는 배우 인터뷰?
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 89.831
# 넘나 재밌게 봤습니다 ㅋㅋ소재도 훌륭하고 스토리도 오랜만에 쨩
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.108
# 화끈한 액션의 반하여 짜증났던 로맨스
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 94.743
# 보통사람 사무엘 L.잭슨과 정상인간 라이언 레이놀즈의 쿵짝이어야 하는데 컹쩍느낌?감독이 좀 인생 얘기하고 싶어하는 것 같았고...권선징악의 프레임을 벗어나려는 모범생의 고뇌?(쿠키를 쫌 30초만 이라도 기다렸다가 해...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 94.230
# 영화보고 감상평 잘 안남기는데 ~제목이 유치해서 기대 1도 안하고 영화인들과 다같이 봤는데 보는내내 입을 다물질 못했네요~끝나고나서 다들 한시간동안 영화 얘기만~추격씬도 최고 음악도 최고 정말 모든것이 최고였어요~
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.498
# 다른것보다 영화 배경으로 나오는 그 도시적인 느낌이라던가 색감이런것들이 좋았음 나는
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.970
# 볼 때 마다 재밌음 그래도 티비에서 해주는 거 보다 영화관에서 사운드 빵빵하게 보는 게 나은 듯
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.486
# 좀 지루하고 너무 영화적인 요소가 많네요 총알다피하고 기가 막힌 타이밍으로 살아나고.. 그나마 액션신은 돈좀쓴것같아 좀 볼만했어요 액션신빼면 사실 볼것도 없는듯 개그코드도 별로였고
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 88.036
# 넘나 재밌게 봤습니다 ㅋㅋ소재도 훌륭하고 스토리도 오랜만에 쨩
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.108
# 화끈한 액션의 반하여 짜증났던 로맨스
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 94.743
# 보통사람 사무엘 L.잭슨과 정상인간 라이언 레이놀즈의 쿵짝이어야 하는데 컹쩍느낌?감독이 좀 인생 얘기하고 싶어하는 것 같았고...권선징악의 프레임을 벗어나려는 모범생의 고뇌?(쿠키를 쫌 30초만 이라도 기다렸다가 해...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 94.230
# 영화보고 감상평 잘 안남기는데 ~제목이 유치해서 기대 1도 안하고 영화인들과 다같이 봤는데 보는내내 입을 다물질 못했네요~끝나고나서 다들 한시간동안 영화 얘기만~추격씬도 최고 음악도 최고 정말 모든것이 최고였어요~
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.498
# 다른것보다 영화 배경으로 나오는 그 도시적인 느낌이라던가 색감이런것들이 좋았음 나는
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.970
# 볼 때 마다 재밌음 그래도 티비에서 해주는 거 보다 영화관에서 사운드 빵빵하게 보는 게 나은 듯
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.486
# 좀 지루하고 너무 영화적인 요소가 많네요 총알다피하고 기가 막힌 타이밍으로 살아나고.. 그나마 액션신은 돈좀쓴것같아 좀 볼만했어요 액션신빼면 사실 볼것도 없는듯 개그코드도 별로였고
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 88.036
# 넘나 재밌게 봤습니다 ㅋㅋ소재도 훌륭하고 스토리도 오랜만에 쨩
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.108
# 화끈한 액션의 반하여 짜증났던 로맨스
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 94.743
# 보통사람 사무엘 L.잭슨과 정상인간 라이언 레이놀즈의 쿵짝이어야 하는데 컹쩍느낌?감독이 좀 인생 얘기하고 싶어하는 것 같았고...권선징악의 프레임을 벗어나려는 모범생의 고뇌?(쿠키를 쫌 30초만 이라도 기다렸다가 해...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 94.230
# 영화보고 감상평 잘 안남기는데 ~제목이 유치해서 기대 1도 안하고 영화인들과 다같이 봤는데 보는내내 입을 다물질 못했네요~끝나고나서 다들 한시간동안 영화 얘기만~추격씬도 최고 음악도 최고 정말 모든것이 최고였어요~
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.498
# 다른것보다 영화 배경으로 나오는 그 도시적인 느낌이라던가 색감이런것들이 좋았음 나는
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.970
# 볼 때 마다 재밌음 그래도 티비에서 해주는 거 보다 영화관에서 사운드 빵빵하게 보는 게 나은 듯
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.486
# 좀 지루하고 너무 영화적인 요소가 많네요 총알다피하고 기가 막힌 타이밍으로 살아나고.. 그나마 액션신은 돈좀쓴것같아 좀 볼만했어요 액션신빼면 사실 볼것도 없는듯 개그코드도 별로였고
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 88.036
# 여러분 불매합시다. 이 영화는 영화감독이 양녀 성추행으로 제작 국가인 북미에서도 개봉하지 못 했으며 주연인 티모시와 몇몇 다른 배우들은 이 영화 출연을 후회한다며 출연료 전액 기부하였습니다.불매해주셨으면 좋겠습니다....
# 부정적인 리뷰
# ----------------------------
# 정확도 : 84.370
# 40살 차이나는 한국계 양딸을 미성년자 때부터 성추행한 감독 '우디 앨런'의 영화입니다. 전세계적으로 논란이 되어서 미국에서도 개봉이 취소되었는데 이걸 한국에서 개봉하다니요? 배우들도 후회된다며 출연료...
# 부정적인 리뷰
# ----------------------------
# 정확도 : 86.284
# 배우들도 개봉반대한 병크 감독 ㅋ
# 부정적인 리뷰
# ----------------------------
# 정확도 : 88.052
# 위 평점 이야기 뼈저리게 공감합니다. 북미에서는 개봉도 안한 작품이고 티모시는 우디앨런과 작업한 것을 후회한다며 출연료 전액을 기부했죠. 티모시 뿐만 아니라 엘르 패닝, 셀레나 고메즈 등 출연진들은 출연료를 기부했습...
# 부정적인 리뷰
# ----------------------------
# 정확도 : 85.873
# 성추행을 떠나서 우디 알렌은 이제 과거의 명성을 죽기 전에 다 까먹으려고 작정한 듯이 영화를 못 만든다
# 부정적인 리뷰
# ----------------------------
# 정확도 : 80.059
# 최악 감독 어린 아이를 7살때부터 성추행한 놈이에요 자국에서도 2년째 개봉 안하는데 이유가 있지 않을까요? 우리나라에서 도대체 이걸 왜 개봉하는 지 모르겠어요;
# 부정적인 리뷰
# ----------------------------
# 정확도 : 91.440
# 티모시 얼굴말고 볼게없음
# 부정적인 리뷰
# ----------------------------
# 정확도 : 94.010
# 전형적인 의식의 흐름 기법
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.768
# 뒷자리 커플 나갈 때 나도 나갈걸... 예술병 걸린 남자놈들과 방황하는 탕아 새끼 뭐 대단한거 깨달았다고... 너무 내 시간 아까움...
# 부정적인 리뷰
# ----------------------------
# 정확도 : 81.353
# 사실, 티모시 별루 안좋아했는데 이영화보고 왜 사람들이 티모시에 광분하는 지 알게됨
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 90.263
# 성범죄자가만든영화입니다
# 부정적인 리뷰
# ----------------------------
# 정확도 : 67.268
# 씨이벌 모르고봤는데 감독이 성추행범; 그걸 떠나서 진짜 재미없어요 교훈도없고 재미도없고 포인트도 모르겠음 진짜 역대급 돈아까운 영화 wow
# 부정적인 리뷰
# ----------------------------
# 정확도 : 98.890
# 스토리가 너무 없음  인스타 갬성 같은 영화
# 부정적인 리뷰
# ----------------------------
# 정확도 : 91.399
# 안개 낀 뉴욕처럼 내용도 희미한 영화
# 부정적인 리뷰
# ----------------------------
# 정확도 : 84.519
# 보는 내내 재즈로 귀가 즐겁고 배우들의 풋풋한 로맨스에 눈이 즐겁다.스크린으로 뉴욕 여행 하고 온 기분
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.087
# 개쓰렠영화. 묘하게 홍상수가 떠오른다. 어린여자 꼬시려고 발정난 늙다리들 3인방과 그걸 또 맞장구 쳐주는 철없는 어린여자(실제로 젊고 어린여자들은 늙다리들에겐 눈길도 안줍니다^^;;) 우디앨런이 평소에 ‘여자’를 어...
# 부정적인 리뷰
# ----------------------------
# 정확도 : 74.279
# 뉴욕, 봄비, 재즈가 다 했다 오랜만에 극장에서 보니 넘나 황홀
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.277
# 감독 본인 이야기 아니냐? 어린 여자애 꼬시려는 아저씨들 얘기가 뭐가 낭만적이야 미친... 그리고 엄마 옛날 얘기 듣고 엄마랑 더 가까워진 거 같다는 게 대체 무슨 맥락인지 이해할 수가 없다...
# 부정적인 리뷰
# ----------------------------
# 정확도 : 79.654
# 낫베드. 전형적인 우디앨런 스타일 영화. OST 기가맥힘. 배우들 기가맥힘. 근데 어딘가모르게 가볍고 우디의 베스트는 아님. 근데 볼만함 추천
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 91.177
# 이젠 정말 보내줘야 해,,, 감독 각본 배우 세명 다 추해보이는게, 앨런이 자학하는건가. 애욕에의 갈망을 변명하는건가.
# 부정적인 리뷰
# ----------------------------
# 정확도 : 85.155
# 낭만적. 음악과 영상이 특히 좋음
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.547
# 감독이 이런 사람인 줄 미리 알았더라면 안봤을텐데..
# 부정적인 리뷰
# ----------------------------
# 정확도 : 78.060
# 우디앨런은 영화판에서 그만 질척거리고 떠나야 할것같다. 처음부터 끝까지 수동적이고 소비적이며 대상화되는 여성 캐릭터에서 그의 사상이 정확히 읽힌다. 학생의 호기심과 열정을 남성중심적인 영화판을 배경으로 해서 이용해먹...
# 부정적인 리뷰
# ----------------------------
# 정확도 : 60.146
# 반짝반짝 빛나는 이 젊고 예쁜 배우들이 이 영화에 다 나온다 ㅋㅋ 뉴욕 여행 가고 싶어지는 영화.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.436
# 비오는 날의 뉴욕과 재즈의 어울림은 환상적이었다 미드나잇인 파리 재밌게 본사람은 무조건 추천!!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.671
# 우디 앨런의 전작 중에선 이레셔널 맨을 대도시 청춘 버전으로 다룬 느낌. 다채롭고 혼란스러우며 낭만적이어서 청춘을 꼭 닮은 도시 뉴욕의 매력에 푹 빠질 수 있다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.940
# 감독이 이런 쓰레기인 걸 알았다면 절대 보지 않았을 영화;; 스토리도 개별로
# 부정적인 리뷰
# ----------------------------
# 정확도 : 96.696
# 감독 병크를 알고도 소비하면 안됩니다 ;;;
# 부정적인 리뷰
# ----------------------------
# 정확도 : 81.211
# 티모시 미모 실화냐.. 티모시 얼굴을 보면 마음이 웅장해진다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 90.056
# 아무데서도 개봉을 안 해주니까, 이 시기에 거의 거저 먹다시피 한국 영화관에서 개봉을 해주는 거겠지. 개봉해주는 한국 영화관들 다 망해라~ㅋㅋㅋ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.404
# 1.티모시의 피아노 연주 최고2.우디앨런 = 범죄자사회면에 나와야하는 문제
# 부정적인 리뷰
# ----------------------------
# 정확도 : 83.019
# 비오는 뉴욕 거리 보니까 금방이라도 떠나고 싶었다 영상미 좋구 배우들 연기도 좋았넹:) 특히 피아노 치며 노래하는 티미 최고시다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.595
# 티모시... 이제 비가 오는 날이면 당신 생각이 제일 먼저 날거ㅇF...☆
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.613
# 지속적으로 소아성애 증세를 보인 감독이라고 알고있음 전 부인이 입양한 아이들을 추행했다는 증언도 많고 결국 그 입양아 중 한 명인 여성과 결혼했다는 건 정말 이상한 일임
# 부정적인 리뷰
# ----------------------------
# 정확도 : 78.513
# 아이고 감독아... 왜그랬어
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 85.875
# 불매합니다.
# 부정적인 리뷰
# ----------------------------
# 정확도 : 81.308
# 대박. 한국에선 개봉했네. 미국에서도 개봉 못 한걸. 어떻게 수입해왔대. 우디앨런 이 놈은 쓰ㄹㄱ인데 왜 계속 영화를 만드는지 몰라. 제발 은퇴해라
# 부정적인 리뷰
# ----------------------------
# 정확도 : 79.760
# 역대급 쓰레기. 절대 보지 마세요.
# 부정적인 리뷰
# ----------------------------
# 정확도 : 98.473
# 역겹다 아동성범죄자가 갈곳은 감방이다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 63.115
# 배우들 다 좋아하는데ㅠㅠ체고야 분위기 미쳐씀
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.006
# 뉴욕... 티모시로 볼이유 너무 충뷴...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 91.409
# 뭔 생각으로 이 영화를 개봉시켰는지 모르겠다;;불매하세요
# 부정적인 리뷰
# ----------------------------
# 정확도 : 95.758
# 성범죄자가 만든 영화 보는 사람도 똑같습니자
# 부정적인 리뷰
# ----------------------------
# 정확도 : 85.233
# 수입사는 개봉 철회하길...수입 결정한거 뼈저리게 후회할꺼다...성범죄자 감독 영화 개봉하다가 쪽박찬다...20대 여성이 좋아하는 음악이 어쩌구 저쩌구..개뿔...
# 부정적인 리뷰
# ----------------------------
# 정확도 : 82.409
# 나만 별론가 배우들이 아까운 내용?
# 부정적인 리뷰
# ----------------------------
# 정확도 : 89.862
# 티미 볼려고 봤는데 뉴욕이 참 예쁘게 나오더라. 중간중간 흐르는 재즈 선율도 좋고, 엘르패닝과 셀레나고메즈도 매력적.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.077
# 전체의 행복을 위해서라면 개인의 행복을 희생해도 괜찮은가
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.990
# 재미 있으면 공감버튼을 눌러주세요
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 85.110
# 미츠하랑 타키나오는데 나중에 타키 할머니 찾아갔을때 할머니 팔목에 미츠하 팔찌를 착용하고있었음 이거보고 신카이 마코토한테 시사회에서 이 뭐냐고 물어봤는데 타키랑 미츠하가 결혼하고 미츠하가 타키 할머니한테 만들어...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 84.768
# 영상미는 좋았는데... 스토리는 아쉬웠음. 떡밥회수도 안되고 그래서 뭘 말하고 싶은건지... 너의이름은 기대하고 보는 사람은 실망 많이 할 듯
# 부정적인 리뷰
# ----------------------------
# 정확도 : 88.741
# 폭풍우가 휩쓸고 간 개연성
# 부정적인 리뷰
# ----------------------------
# 정확도 : 62.315
# 비 오는 날이 그리 나쁘지만은 않은 것 같다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.628
# 미츠하는 백화점에서 일하고있었다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 92.591
# 아이맥스 폭죽놀이는 역대급이다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 89.376
# 도쿄 쑥대밭 만든 건 볼만했음.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 93.937
# 스토리는 호불호 갈리겠지만 눈이랑 귀가 너무 즐겁다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.465
# 전작만큼을 기대하고 가면 많이 아쉬울 것. 재미가 그닥 없음. 하지만 OST와 작화는 여전하니 눈뽕 귀뽕 맞고싶으면 강추.
# 부정적인 리뷰
# ----------------------------
# 정확도 : 81.608
# 다수를 위한 소수의 희생은 정당한가? 어른들은 이해할 수 없는 아이들의 동화같은 이야기
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.344
# 다 좋은데 총 은 왜 나온걸까...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 65.302
# 개연성 없는 스토리.. 난데없는 가출에 비는 계속 내리는 설정 날씨의 무녀는 갑툭튀.. 오글거림.. 단 영상미는 최고임. 결말은 그들만의 해피엔딩.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 72.638
# 나는 스가한테 감정이입 된다 마음속의 일렁임과 현실과의 타협 그 중간에서 요동치는 모습
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.783
# 호다카 얘기는 왜 1도 안보여줌? 그래서 얘가 왜 가출했고 집에 돌아가기 싫어하는 이유가 뭔데??
# 부정적인 리뷰
# ----------------------------
# 정확도 : 54.655
# 각본가를 따로 구해보는게 어떨지. 작화랑 OST는 최고지만 과하다. 몰래 온 손님은 반갑다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.954
# 아 마지막장면 또 보고싶음 작화랑 ost는 절대 못까요 최고였음
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.712
# 너의 이름은 만큼은 아니지만 재밌게 봤습니다 작화가 너무 이쁜듯합니다 나오는 노래도 좋았습니다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.263
# 진짜 어거지 급전개가 너무 심각하고 결말은 엉성하다. 영상미랑 OST만 보고 고평가하기엔 내용이 너무 부실하다
# 부정적인 리뷰
# ----------------------------
# 정확도 : 63.420
# 발전된 기술. 퇴보한 감성.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 89.009
# 영상, 음악, 내용 너무나 좋은 영화 였습니다. 괜찮아. 위로의말이 계속 남아요
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.858
# 호다카가 계단 올라갈 때 OST 갑자기 커지는 순간 너의 이름은 엔딩처럼 전율 돋음 ㄹㅇ;
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.260
# 신카이마코토 전작을 다 훑어봤다면 이번 날씨의 아이 작화는 진짜 한계를 뛰어넘은듯한 느낌입니다. 본격 힐링영화라는 말은 당연하구요. 두번정돈 더 보러갈 예정입니다! 스토리면에서는 확실히 너의이름은이 더 탄탄하긴 한데...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.764
# 색감이 너무나 아름다워 스크린에서 눈을 뗄 수 없었음..ㅠㅠ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.096
# 이영화는 집단(도쿄)응 위해 개인(히나)의 희생을 당연시하는 일본 전체주의를 비판하는 영화 입니다결말을 보시면 아시겠지만 결국 도쿄가 물에 잠기는 엔딩인데 감독은 근대부터 이뤄진 일본의 전체주의사상을 비판하는 메세지...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 90.989
# 솔직히 재미가 없진 않은데  보면서 너의 이름은 보다 스토리,개연성,떡밥 회수 가 너무 떨어져서 보는 내가 다 민망 했음.그림체,OST는 진화했지만 그밖의 중요 요소는 퇴보...솔직히 이번엔 박평식 평점에 공감
# 부정적인 리뷰
# ----------------------------
# 정확도 : 70.285
# 감동적이고 좋은데 중간중간 계속 나오는 여캐몸이나 속옷 같은건 왜 계속 부각하는건지 모르겠어요ㅠ 재밌게 보다가도 중간중간 흐름 깬다고해야하나 그래서 1점 깎았엉
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 80.545
# 이 맛에 애니메이션 보는거지. 애니메이션은 상상력이고 한계가 없어야 한다고 생각함. 현실 드라마같기만 한 애니메이션이 대체 무슨 매력일까? 작가 특유의 감성도 돋보였고 거기에 어우러진 음악도 최고였다. 어릴때 만화 ...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 93.693
# 스토리를 발로쓴건가 진짜 총기 액션인지 판타지인지 일본식 변태물인지 작화는 레전드
# 부정적인 리뷰
# ----------------------------
# 정확도 : 82.079
# 남주가 초반에 조금만 정조준했으면 애니판 조커 볼뻔
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 64.742
# 메시지가 괜찮았음. 총이 뭐긴.. 맥거핀이지ㅋㅋㅋ 굳이 총에 의미 부여 하자면 가출과 마찬가지로 자유를 상징하겠지요. 그리고 떡밥회수 운운하는 분들은 영화를 헛 보신 것. 제가 생각하는 영화의 주제는 이렇습니다. [...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 91.400
# 폭풍우가 휩쓸고 간 개연성
# 부정적인 리뷰
# ----------------------------
# 정확도 : 62.315
# 이제 평생 비가 와도 괜찮다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.968
# 믿고보는 감독인듯 스토리는 전형적인 일본 애니메이션이라 몰입이 안될뻔 했는데 영상미가 너무 좋아서 몰입하게 만드네여 한번 더 볼 예정입니다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.250
# 연고도 없는 놈 재워주고 먹여줘도 돌아오는건 총구뿐이여
# 부정적인 리뷰
# ----------------------------
# 정확도 : 67.077
# 너의 이름은때의 그 감동과 여운이 없어 아쉬웠다 전작이 워낙 명작이어서 기대를 너무 하고 본것같다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.869
# 떡밥회수 몇개빼고는 진짜 최고였다 너의이름은 아련하고 누군가를 찾게된다면 이거는 기분이 좋아지는 영화
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.185
# 비로 가득한 세상을 맑게 해주었던 소녀와 소년이 보여준 순수함은 개봉 전 기대했던 그 이상의 감동을 선사했다. 정말 오랫동안 여운이 남을 명작이다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.662
# 도쿄 사람들이 나쁜짓 해서 물바다가 되었군요ㅜㅜ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 59.004
# 전 작품인 '너의 이름은' 에 비해 스토리 구성이 매우 단순하고 개연성도 부족하고, 여러가지로 기대에 비해 많이 부족해서 실망함. 비추임.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 70.106
# 너의 이름은 생각하고 보면 상당히 실망할 수 있음.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.850
# 한번 더 보러 갈예정 영상미 좋고 음악좋고 마지막엔 울었다 마코토 감독은 천재임
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.785
# 개연성이 없다고들하는데 어떤게 개연성이없는건지요?한국영화에 너무익숙해진게 아닌가요? 남주가 왜집을 나갔는지에 대한 이유가 꼭 있어야하나요 그영화에서 그이유가 필요한 이유는 무엇인가요 그리고 스토리를까는이유는 왜인가요...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 56.326
# 떡밥 회수가 너무 안됨 . 그냥 영상미 ost 로 보는 것 같다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 62.435
# 비가 오는 날, 당신을 만났기에 나는 비오는 날이 좋다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.308
# 기자들 리뷰가, 특히 박평식 마저...너무 좋아서 궁금했던 작품. 근데 영화를 보고 나니 그 리뷰들은 이 영화의 진짜를 반도 담아내지 못한 느낌이다. 로레야 사랑해~!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.067
# 톰보이 너무 좋게 봤어요... 잔잔한 듯 하지만 감정적 스릴러라 불러도 좋을만큼 강렬하고 여운이 깊은 영화였습니다. 특히 로레에게 많이 공감됐어요.. 어릴 때 나에게로 돌아가서 이 영화를 보여줄 수 있다면 좋았을 거...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.027
# 아이가 자신의 존재와 의미를 온전히 받아들일 때까지 어른은 어떤 자세를 취해야 하는가 생각해보게 된다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.714
# 햇살처럼 따듯하고 상큼한 영화 . 요즘같은때 보고 힐링하고 싶은영화 . 내 청소년기 생각이 났어요. 그리고 부모님들도 보시면 생각할꺼리가 많은 영화라고 생각해요. 강력추천합니다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.493
# 셀린 시아마 감독의 섬세한 시선이 담겨서 너무 좋았다ㅠㅠ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.621
# 잔의 통통한 손이 카메라에 잡힐때마다귀여움에 죽을뻔함...두 자매의 매력.. 아이의 성장기..
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.539
# 아이들의 연기도, 영화의 색감도, 대사의 마디마디가 계속 생각난다. 여운이 깊다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.799
# 와우 그들의 마음이 이렇게나 잘 이해되다니..
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.589
# 숨고 싶은, 숨기고 싶은 세상을 만든 어른 중 한 사람으로서 미안해.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.847
# 과거로 돌아가고싶을때마다 꺼내보고싶은 영화다. 어릴때 이영화를 봤다면 정신적으로 덜 외로웠을까.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.206
# 로레건 미카엘이건 무슨 상관이겠어
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 89.423
# 인생영화. 아직도 ost를 들으면 울컥한다. 로레가 행복하길, 여성들이 행복하길
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.529
# 어린 아이의 순수함 때문인지 불편함 없이 볼 수 있었다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.527
# 믿고 봤고 당연하게 감동했다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.471
# 파란색 원피스가 이처럼 폭력적으로 다가올지 몰랐다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 88.763
# 아 진짜 간만에 좋은영화봤어요ㅠㅠ
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.192
# 로레이든 미카엘이든 그게 중요할까? 그저 그녀 자신일 뿐이다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 57.298
# 보는내내 가슴이 따뜻해지는 영화였어요~
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.701
# 어린시절 치마를 싫어했던 여자라면 모두 공감할수 있는 영화. 감동
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.386
# 파란 원피스를 입은 로레든 빨간 바지를 입은 미카엘이든 사랑스러운 아이..어느쪽이든 지지해주고 싶다! 잔..너무 귀여움*
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 94.582
# 동생에게 입덕했습니다,, 순수함 그자체의 아무 편견도 묻지 않은 아이의 시선
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.383
# 셀린 시아마는 천재야..
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 94.576
# 보는 내내 마음이 찡했다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.801
# 셀린 시아마 감독님은 소리와 음악을 절제하다가 특정한 장면에서 터뜨리는 능력이 있다. I love you always가 계속 생각난다. 미카엘을 안아주고 싶었던 영화
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.218
# 극장에서 4번 봤어요. 조만간 또 볼 거예요. 2011년도 영화라고 믿기지 않아요. 볼때마다 더 울게 된다며...로레 미카엘! 널평생사랑할거야!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.792
# 아직까지도 나 자신에게 계속 반복되는 질문을 여기서 함께 느껴지게 반드는 영화가 아닐지, 강추!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.530
# 사랑스러운 자매애를 보여주는 로레와 잔. 둘이 오로지 자신으로서 늘 행복하기를.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.257
# 모든 합이 이렇게나 잘 맞을 수 있을까. 여름이 다가오는 계절 가슴이 두근거린다. n차 찍으러 가야지...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.230
# 좋았어요. 꼭 보세요!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.994
# 타오르는 여인의 초상의 이 감독은 경계에 서있는 인물의 감정을 다루는데 탁월하다. 새로운 곳으로 이사를 하면서의 설레임, 친구들과 어울리고 싶은 마음과 드러내고 싶지 않은 것과의 갈등 등 아이의 시점에서 다뤘기에 특...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.045
# 뭐 하나 빠지는게 없는 감동적인 성장 영화
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.736
# 오랜만에 충만하고 아름다운 감정을 느끼게 해준 소중한 영화♡
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.470
# 영화 우리들이랑 닮은 영화 초록초록한것도 좋고 연출력 연기력 다 좋음동생으로 나오는 잔 너무 귀엽
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.883
# 가서 꼭 안아주고 싶은 사랑스러운 영화
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.333
# 뭐가 됐건 널 사랑해, 언제나
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 94.893
# 모든게 완벽했던 따뜻한 햇살 한 줄기와 같았던 작품
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.558
# 여성들에게 필요한 성장영화.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.641
# 있는 그대로도 괜찮아. 나도 몰랐던 마음의 생채기를 따뜻하게 토닥여주는 영화.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 98.716
# 한국의 톰보이들과 함께 로레의 이야기를 볼 수 있어서 좋았습니다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.964
# 로레의 시선에서 몰입할 수 있는 좋은 영화였습니다. 많은 톰보이들과 함께해서 더욱 뜻깊었어요. 세상의 모든 로레들 화이팅.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.889
# 간만에 잔잔한 감동을 주는 재미있는 영화였다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.875
# 나는 나일 때 가장 빛난다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 88.977
# 나는 그대로 나라는 사람인데 세상은 자꾸 나를 다른 모습으로 정의하려고 한다. 어째서일까?자라며  한 번이라도 의문을 가져 본 사람은 주인공에게 자신을 대입하며 볼 수 있을 영화. OST의 연출 역시 감독의 이후 작...
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 96.757
# 조금 다르지만 그래서 아름다울 수 있음을 보여주는 영화.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.661
# 담담하고 잔잔하게 이야기를 하는데 영화를 보고 나면 내 안에서 뭔가가 울컥하고 끓어오르는 느낌이 든다.
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 92.041
# 상영 후에도 여운이 남는 의미있는 영화여서 기억에 남을것 같습니다
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.587
# 모든 게 다 완벽히 좋았던 영화였음ㅠ 뭉클
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 97.410
# 오랜만에 여운이 남는 좋은 영화였어요!!!아이들의 연기는 자연스럽고, 동생 쟌은 사랑스럽고..미카엘의 눈빛이 인상적이였어요!!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 99.957
# 솔트박이 감성적일 만한 영화... 마지막에 난 로레야 하는데 진심 폭풍 울림 휴... 기획전 이후로 두번 봤는데도 좋음.. 3차 간다...!!
# 긍정적인 리뷰
# ----------------------------
# 정확도 : 95.930

# %%
final_result.head(50)  #1 긍정, 0 부정
# Out:
#                                                    리뷰        정확도 결과  평점  \
# 0                              이것은... 사진 세울 때 쓰는 겁니다ㅎ  95.860836  1  10
# 1   영화 재밌습니다. 다니엘 래드클리프 완전 열연이네요. 열쇠맞출때마다 몰입감과 긴장감...  99.708120  1  10
# 2                        다니엘 래드클리프.. 이제는  배우로 도약하는거같다  97.574590  1  10
# 3           심장 쫄리는 수준이 장난 아님. 말도 안 되는 것 같은데 실화라니 더 충격  97.623413  1  10
# 4   코로나 탈출 방탈출 같이 갇힌 공간을 탈출하고 싶은 그 맘이 커서 그런지 재밌게 봤...  98.915650  1  10
# 5                         나라면 그냥 12년 살았을듯....쫄려 죽는줄..  89.423751  1  10
# 6                                        몰입도라든가 연출이좋음  98.318110  1   8
# 7   껌으로 열쇠 붙일때가 젤 긴장감 있었다ㅋㅋㅋ 스토리는 실화기반이라 독특한 느낌은 없...  97.763919  1   7
# 8   진짜 너무 재밌음 제빌 봐주세요 부탁임 이건 꼭 뵈야됨 콜라 빨대 오무리면서 봤네 ...  97.418327  1  10
# 9                             긴장감,몰입감, 통쾌함을 느낀  재미난영화  97.930653  1   8
# 10          영화속에 실제 탈출 주인공 나온다. . . 면회하는 장면. . . 잘바바요  89.524816  1  10
# 11  그동안 봐온 감옥탈출 영화중 가장 소박했지만 열쇠라는 작은 매체 하나만으로 이렇게 ...  97.632681  1   9
# 12                            이게 실화라니... 진짜 대단하다.. ㄷㄷ  93.683929  1   9
# 13                       위험을 무릅쓰고 행동하는 자만이, 자유를 만끽하는법  96.672247  1   9
# 14  배우들이 대사를 하는 시간보다 숨소리를 내는 시간이 더많은 영화오히려 그런 상황이 ...  91.622049  1   7
# 15                         오 다니엘 래드클리프 인생 영화!  재밌어요~~  99.924352  1  10
# 16                                  실화인데 영 믿기지가 않은 영화  94.001515  1   8
# 17                        처음부터 끝까지 심장이 아주 쫄깃쫄깃 조여온다..  96.897548  1   8
# 18  실화라는게 믿겨지지 않을 정도로 영화같은 스토리였네요, 코로나 때문에 오랜만에 간 ...  97.108816  1   9
# 19                                        이런 영화 처음이네~  91.428548  1  10
# 20                      아들과 봤음 조마조마 조마조마 실화 라니 정말 ...  97.727816  1   8
# 21  15개의 강철문을 뚫는건 오로지 열쇠뿐!!!...시종 가슴을 조여오는 긴장감은 압권...  98.607187  1  10
# 22  탈출영화 좋아해서 봤는데 직접 열쇠를 만들어버리는 클라쑤 ㅋㅋㅋㅋ 새로운 느낌이었는...  99.348857  1   9
# 23  생각보다 자극적인 탈출 장면은 없어서 아쉽지만 들킬까봐 심장 쫄린 장면은 많았다. ...  98.870926  1   7
# 24                           이야 몰입감쩔고 개쫄림 탈옥과정을 잘 표현함  98.731373  1   8
# 25  긴장감 넘치는 연출로 몰입감이 좋아 시간가는 줄 모르고 빠져서 보게됩니다. 특히 실...  99.476998  1   8
# 26  끝나는시간까지맘졸이며재미있게봤어요.실화가바탕이라고했으나내용을모르고가서인지보는내 긴장...  97.042696  1  10
# 27  상황이 너무 맞아떨어지는 느낌도 들지만 탈출과정이 주는 몰입감은 최고... 더러운 ...  98.150956  1   8
# 28                                  공포영화 보다도 더 심장터질뻔!  97.580045  1  10
# 29           해리포터 이후 다니엘 래드클리프 작품 중에서 제일 나은듯 긴장감 장난아님  95.886100  1   8
# 30              정적인 플롯이라고 생각했는데 생각보다 긴장감 넘치고 몰입됨. 재밌음  98.709051  1   7
# 31  가학적인 장면 없이도 충분히 괴로운 영화 시종일관 꽉 죄어오는 긴장감이 관객을 괴롭힌다.  95.989536  1   7
# 32  영화 볼 게 없어서 고른 건데 과몰입해서 봤음열쇠 껌으로 주울 때 긴장돼서 발가락을...  95.169129  1   7
# 33  거짓말같은 실화라서 열쇠하나만으로도상영내내 긴장감 최고!인권운동가들에게응원과 박수를...  99.523671  1  10
# 34                                        보다가 심장병 걸릴뻔  68.565206  0   9
# 35                                해리포터의 아즈카반 탈출 영화화 ㅋ  95.833923  1   9
# 36                                      진짜 짜릿해 ~~~~ 요  96.979750  1  10
# 37      와~ 심장 쫄깃해 죽는줄 알았다... 이게 진짜 실화? 감옥 탈출 영화의 최고봉!  96.586535  1  10
# 38                      내용도 재미있고 특히 실화라는게 ㅋㅋ임팩트 있었습니다  95.266432  1  10
# 39                                  같이 탈옥 한번 한것 같은 기분  99.281220  1   9
# 40                      극장에서 봐야하는 영화 was the best !:)  99.301624  1  10
# 41                               몰입도가 좋아서 재미있게 잘봤습니다~  99.546095  1   9
# 42  현실에 저항하는 것이 우리나라 독립운동가들 같기도 해서 응원(?)하면서 봤네요. 실...  99.568182  1  10
# 43           내 인생 최고의 영화 꼭 보세요. 10점!! 불면증에 큰 도움이 됩니다.  99.670138  1  10
# 44                    긴장감이 말이 필요없어요 꼭 보세요 간만에 인생영화 등극  99.989027  1  10
# 45                            보다가 심장떨려서 죽을뻔했어용 꿀잼 ㅋㅋㅋ  91.874162  1  10
# 46  영화를 끝까지 보고 나서도 이게 실화라는 게 믿기지 않을 정도로 정말 놀라운 감옥 ...  95.790019  1  10
# 47                               말이 필요없음. 이런걸 영화라고 함.  93.296021  1  10
# 48                                레미제라블이후로 휴잭맨의인생영화였다  99.925107  1  10
# 49  휴잭맨의. 매력이 한껏 돋보인 영화입니다.다른 출연자들도 너무 멋지구요.사람은 누구...  98.918631  1   9
#
#                      작성자                날짜  movie_id
# 0     sereniTY(rldj****)  2020.05.06 20:13       1.0
# 1        영화매니아(yhib****)  2020.05.06 11:02       1.0
# 2         짱구아빠(cool****)  2020.05.06 14:45       1.0
# 3         눈누난나(lovn****)  2020.05.06 14:47       1.0
# 4     내일의내가하겠지(toie****)  2020.05.06 11:37       1.0
# 5          이연희(92-y****)  2020.05.09 23:25       1.0
# 6          RED(xx41****)  2020.05.06 12:44       1.0
# 7          빌헬미(jwjw****)  2020.05.06 15:22       1.0
# 8          김병근(dkzp****)  2020.05.06 19:59       1.0
# 9               raba****  2020.05.09 20:39       1.0
# 10              wjoh****  2020.05.11 07:29       1.0
# 11        멘탈천국(5333****)  2020.05.07 22:22       1.0
# 12        계란머리(sdb9****)  2020.05.06 15:05       1.0
# 13              pon0****  2020.05.06 15:14       1.0
# 14        저녁노을(pqqv****)  2020.05.16 21:52       1.0
# 15        곰곰19(rhar****)  2020.05.06 11:39       1.0
# 16         epr(epro****)  2020.05.10 19:14       1.0
# 17  Sea Squirt(lcs6****)  2020.05.15 16:46       1.0
# 18        BLUE(heoj****)  2020.05.06 14:48       1.0
# 19         Joy(joy0****)  2020.05.06 13:34       1.0
# 20         타일러(itsh****)  2020.05.07 21:11       1.0
# 21         이남훈(nhsk****)  2020.05.08 10:58       1.0
# 22          리치(desi****)  2020.05.06 15:00       1.0
# 23          헬로(sunj****)  2020.05.14 11:09       1.0
# 24          문기(gye1****)  2020.05.13 16:09       1.0
# 25          꼴깍(yosu****)  2020.05.06 14:53       1.0
# 26              dude****  2020.05.08 18:38       1.0
# 27      castco(hand****)  2020.05.08 02:09       1.0
# 28              tjdg****  2020.05.14 12:25       1.0
# 29         클린봇(osy6****)  2020.05.08 03:24       1.0
# 30   Dayflower(hkh9****)  2020.05.10 23:07       1.0
# 31         토리파(manj****)  2020.05.11 03:18       1.0
# 32         김아름(yim4****)  2020.05.10 21:36       1.0
# 33         보리비(call****)  2020.05.15 16:30       1.0
# 34         REY(heyd****)  2020.05.11 00:52       1.0
# 35         불효자(silb****)  2020.05.07 19:47       1.0
# 36   treffshop(pdj4****)  2020.05.25 22:34       1.0
# 37        오늘밤새(inst****)  2020.05.16 08:55       1.0
# 38         한들꽃(jesu****)  2020.05.06 14:46       1.0
# 39         박종운(pgw0****)  2020.05.24 17:20       1.0
# 40   Amberlina(davi****)  2020.05.16 23:05       1.0
# 41              wooj****  2020.05.06 17:04       1.0
# 42         토마스(agac****)  2020.05.24 01:13       1.0
# 43          토루(tato****)  2020.05.23 18:11       1.0
# 44      제이비 JB(jbji****)  2020.05.17 00:55       1.0
# 45         che(rha0****)  2020.05.16 23:21       1.0
# 46      donnie(tech****)  2020.05.14 21:15       1.0
# 47              ryan****  2017.12.20 07:21       2.0
# 48         김도영(rlae****)  2017.12.20 00:03       2.0
# 49              sunn****  2017.12.20 15:19       2.0

# %%
def df_to_list(df):
    review=final_result['리뷰'].tolist()
    accuracy=final_result['정확도'].tolist()
    result=final_result['결과'].tolist()
    # score=final_result['평점'].tolist()
    reviewer=final_result['작성자'].tolist()
    date=final_result['날짜'].tolist()
    movie_id=final_result['movie_id'].tolist()
    return review, accuracy, result, reviewer, date, movie_id

# %%
def db_connect(final_result):
    review, accuracy, result, reviewer, date, movie_id = df_to_list(final_result)

    conn = pymysql.connect( #DB연결
    host='localhost',
    user='root',
    password='1234',
    db='movie_review',
    charset='utf8' 
    )
    total = len(review) #리뷰 개수
    curs = conn.cursor()
    sql = "insert into reviews(review_id, review_movie_id, review_contents, review_accuracy, review_result, review_reviewer, review_date) values(%s,%s,%s,%s,%s,%s,%s)"
    for i in range(total):
        curs.execute(sql, (i+1 ,movie_id[i], review[i], accuracy[i], result[i], reviewer[i], date[i]))
        print('ok')    
        conn.commit()

# %%
db_connect(final_result)
# Out:
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
